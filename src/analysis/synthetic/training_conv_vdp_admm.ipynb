# %%
from utils.analyse_results import GraphsTraining, Results, load_all_pickles, plot_time_bands

train_info = GraphsTraining()

# %%
from analysis.synthetic import analyze_admm_results

df = analyze_admm_results.main([
    "--dir", "results/admm_runs",
    "--file", "admm_results_2026-01-11_17-05-05.pkl",
])
# Out:
#                                      file  run  iter     seed  \
# 0    admm_results_2026-01-11_17-05-05.pkl    0     0  6569800
# 1    admm_results_2026-01-11_17-05-05.pkl    0     1  6569800
# 2    admm_results_2026-01-11_17-05-05.pkl    0     2  6569800
# 3    admm_results_2026-01-11_17-05-05.pkl    0     3  6569800
# 4    admm_results_2026-01-11_17-05-05.pkl    0     4  6569800
# ..                                    ...  ...   ...      ...
# 595  admm_results_2026-01-11_17-05-05.pkl   29    15  9339907
# 596  admm_results_2026-01-11_17-05-05.pkl   29    16  9339907
# 597  admm_results_2026-01-11_17-05-05.pkl   29    17  9339907
# 598  admm_results_2026-01-11_17-05-05.pkl   29    18  9339907
# 599  admm_results_2026-01-11_17-05-05.pkl   29    19  9339907
#
#      primal_residual   mse_train  mse_coll_train    mse_test  mse_coll_test  \
# 0          43.872472  226.641778             NaN  504.944721            NaN
# 1          43.872472  226.589537             NaN  504.944715            NaN
# 2          85.573503   51.263186             NaN  451.327922            NaN
# 3          11.598049   29.951098             NaN   26.864579            NaN
# 4           6.781028   13.899306             NaN   14.911727            NaN
# ..               ...         ...             ...         ...            ...
# 595         0.224957    0.733305             NaN    0.388476            NaN
# 596         0.214948    0.287838             NaN    0.396238            NaN
# 597         0.205153    0.724327             NaN    0.058746            NaN
# 598         0.195511    0.676316             NaN    0.197002            NaN
# 599         0.185872    0.819895             NaN    0.437439            NaN
#
#      time_elapsed
# 0       15.805304
# 1       16.270276
# 2       26.282258
# 3       30.107685
# 4       33.499234
# ..            ...
# 595     63.252085
# 596     63.974677
# 597     64.731348
# 598     65.464211
# 599     66.176165
#
# [600 rows x 10 columns]

# %%
results_li_32 = load_all_pickles("results/admm_runs/pyomo_vdp_32_140126", recursive=False)
results_df_32 = Results.flatten_convergence_data(results_li_32, model_type="pyomo")
# Out:
# Loaded results/admm_runs/pyomo_vdp_32_140126/1117650015_2026-01-15_05-03.pkl
# Loaded results/admm_runs/pyomo_vdp_32_140126/129774954_2026-01-15_00-21.pkl
# Loaded results/admm_runs/pyomo_vdp_32_140126/1325672458_2026-01-14_18-43.pkl
# Loaded results/admm_runs/pyomo_vdp_32_140126/1626976517_2026-01-14_20-00.pkl
# Loaded results/admm_runs/pyomo_vdp_32_140126/2441749041_2026-01-14_17-22.pkl
# Loaded results/admm_runs/pyomo_vdp_32_140126/2454595405_2026-01-15_02-52.pkl
# Loaded results/admm_runs/pyomo_vdp_32_140126/2499194669_2026-01-14_20-37.pkl
# Loaded results/admm_runs/pyomo_vdp_32_140126/2634218535_2026-01-15_06-12.pkl
# Loaded results/admm_runs/pyomo_vdp_32_140126/300393261_2026-01-14_23-17.pkl
# Loaded results/admm_runs/pyomo_vdp_32_140126/3502209776_2026-01-15_07-13.pkl
# Loaded results/admm_runs/pyomo_vdp_32_140126/3567665415_2026-01-15_08-20.pkl
# Loaded results/admm_runs/pyomo_vdp_32_140126/3971311130_2026-01-15_01-31.pkl
# Loaded results/admm_runs/pyomo_vdp_32_140126/508309730_2026-01-14_22-27.pkl
# Loaded results/admm_runs/pyomo_vdp_32_140126/613153797_2026-01-15_03-50.pkl
# Loaded results/admm_runs/pyomo_vdp_32_140126/739332884_2026-01-14_19-17.pkl
# Loaded results/admm_runs/pyomo_vdp_32_140126/739613127_2026-01-14_21-31.pkl
#
# Loaded 16 files from results/admm_runs/pyomo_vdp_32_140126

# %%
results_df_32["mse_train"] = results_df_32["mse_train_coll"]
results_df_32["mse_test"] = results_df_32["mse_test_coll"]

# %%
df["pretrain"] = False
results_df_32["pretrain"] = False

# %%
results_df_32.head()
# Out:
#   param1  param2   param3  time_elapsed  \
# 0    vdp    True  0.01000      0.750668
# 1    vdp    True  0.01416      0.743992
# 2    vdp    True  0.02664      0.738738
# 3    vdp    True  0.04745      0.754096
# 4    vdp    True  0.07657      0.751059
#
#                                    direct_model_pred  \
# 0  [[-0.026391157748692395, -0.02594990882574195,...
# 1  [[-0.026391157748692395, -0.02594990882574195,...
# 2  [[-0.026391157748692395, -0.02594990882574195,...
# 3  [[-0.026391157748692395, -0.02594990882574195,...
# 4  [[-0.026391157748692395, -0.02594990882574195,...
#
#                                          odeint_pred  \
# 0  [[0.0, 1.0], [0.00038700577, 0.999969], [0.002...
# 1  [[0.0, 1.0], [0.00038700577, 0.999969], [0.002...
# 2  [[0.0, 1.0], [0.00038700577, 0.999969], [0.002...
# 3  [[0.0, 1.0], [0.00038700577, 0.999969], [0.002...
# 4  [[0.0, 1.0], [0.00038700577, 0.999969], [0.002...
#
#                                     odeint_pred_test  mse_train   mse_test  \
# 0  [[-2.3152602, 0.26493636], [-2.3159971, 0.2638...  12.211985  13.520446
# 1  [[-2.3152602, 0.26493636], [-2.3159971, 0.2638...  12.211985  13.520446
# 2  [[-2.3152602, 0.26493636], [-2.3159971, 0.2638...  12.211985  13.520446
# 3  [[-2.3152602, 0.26493636], [-2.3159971, 0.2638...  12.211985  13.520446
# 4  [[-2.3152602, 0.26493636], [-2.3159971, 0.2638...  12.211985  13.520446
#
#    mse_train_coll  mse_test_coll    termination          seed
# 0       12.211985      13.520446  maxIterations  1.117650e+09
# 1       12.211985      13.520446  maxIterations  1.117650e+09
# 2       12.211985      13.520446  maxIterations  1.117650e+09
# 3       12.211985      13.520446  maxIterations  1.117650e+09
# 4       12.211985      13.520446  maxIterations  1.117650e+09

# %%
df
# Out:
#                                      file  run  iter     seed  \
# 0    admm_results_2026-01-11_17-05-05.pkl    0     0  6569800
# 1    admm_results_2026-01-11_17-05-05.pkl    0     1  6569800
# 2    admm_results_2026-01-11_17-05-05.pkl    0     2  6569800
# 3    admm_results_2026-01-11_17-05-05.pkl    0     3  6569800
# 4    admm_results_2026-01-11_17-05-05.pkl    0     4  6569800
# ..                                    ...  ...   ...      ...
# 595  admm_results_2026-01-11_17-05-05.pkl   29    15  9339907
# 596  admm_results_2026-01-11_17-05-05.pkl   29    16  9339907
# 597  admm_results_2026-01-11_17-05-05.pkl   29    17  9339907
# 598  admm_results_2026-01-11_17-05-05.pkl   29    18  9339907
# 599  admm_results_2026-01-11_17-05-05.pkl   29    19  9339907
#
#      primal_residual   mse_train  mse_coll_train    mse_test  mse_coll_test  \
# 0          43.872472  226.641778             NaN  504.944721            NaN
# 1          43.872472  226.589537             NaN  504.944715            NaN
# 2          85.573503   51.263186             NaN  451.327922            NaN
# 3          11.598049   29.951098             NaN   26.864579            NaN
# 4           6.781028   13.899306             NaN   14.911727            NaN
# ..               ...         ...             ...         ...            ...
# 595         0.224957    0.733305             NaN    0.388476            NaN
# 596         0.214948    0.287838             NaN    0.396238            NaN
# 597         0.205153    0.724327             NaN    0.058746            NaN
# 598         0.195511    0.676316             NaN    0.197002            NaN
# 599         0.185872    0.819895             NaN    0.437439            NaN
#
#      time_elapsed  pretrain
# 0       15.805304     False
# 1       16.270276     False
# 2       26.282258     False
# 3       30.107685     False
# 4       33.499234     False
# ..            ...       ...
# 595     63.252085     False
# 596     63.974677     False
# 597     64.731348     False
# 598     65.464211     False
# 599     66.176165     False
#
# [600 rows x 11 columns]

# %%
plot_time_bands(
    {"admm": df, "single": results_df_32},
    y_col="mse_train",  # or "mse_test"
    title="Training MSE",
    logy=True,
    align_grid = False,
    xlim =(0, 40)   
)
# Out:
# /Users/mariiashapo/Library/CloudStorage/OneDrive-Personal/project_2324/NODE/src/utils/analyse_results.py:702: RuntimeWarning: Mean of empty slice
#   mean_L = np.nanmean(L, axis=0)
# /Users/mariiashapo/anaconda3/envs/node_25/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# <Axes: title={'center': 'Training MSE'}, xlabel='Training Time (s)', ylabel='Mse Train (log scale)'>

# %%
plot_time_bands(
    {"admm": df, "single": results_df_32},
    y_col="mse_test",  # or "mse_test"
    title="",
    logy=True,
    align_grid = False,
    xlim =(0, 40)   
)
# Out:
# /Users/mariiashapo/Library/CloudStorage/OneDrive-Personal/project_2324/NODE/src/utils/analyse_results.py:702: RuntimeWarning: Mean of empty slice
#   mean_L = np.nanmean(L, axis=0)
# /Users/mariiashapo/anaconda3/envs/node_25/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# <Axes: xlabel='Training Time (s)', ylabel='Mse Test (log scale)'>

# %%
plot_time_bands(
    pyomo_comparison_dfs,
    y_col="mse_test",  # or "mse_test"
    title="Testing MSE — Pyomo vs JAX vs PyTorch",
    logy=True,
    align_grid = False
)
# Out:
# /Users/mariiashapo/Library/CloudStorage/OneDrive-Personal/project_2324/NODE/src/utils/analyse_results.py:702: RuntimeWarning: Mean of empty slice
#   mean_L = np.nanmean(L, axis=0)
# /Users/mariiashapo/anaconda3/envs/node_25/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# <Axes: title={'center': 'Testing MSE — Pyomo vs JAX vs PyTorch'}, xlabel='Training Time (s)', ylabel='Mse Test (log scale)'>

# %%
plot_time_bands(
    pyomo_comparison_dfs,
    y_col="mse_test",  # or "mse_test"
    title="Testing MSE — Pyomo vs JAX vs PyTorch",
    logy=True,
    align_grid = False
)
# Out:
# /Users/mariiashapo/Library/CloudStorage/OneDrive-Personal/project_2324/NODE/src/utils/analyse_results.py:702: RuntimeWarning: Mean of empty slice
#   mean_L = np.nanmean(L, axis=0)
# /Users/mariiashapo/anaconda3/envs/node_25/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# <Axes: title={'center': 'Testing MSE — Pyomo vs JAX vs PyTorch'}, xlabel='Training Time (s)', ylabel='Mse Test (log scale)'>

# %%
plot_time_bands(
    pyomo_comparison_dfs,
    y_col="mse_test",  # or "mse_test"
    title="Testing MSE — Pyomo vs JAX vs PyTorch",
    logy=True,
    align_grid = False
)
# Out:
# /Users/mariiashapo/Library/CloudStorage/OneDrive-Personal/project_2324/NODE/src/utils/analyse_results.py:702: RuntimeWarning: Mean of empty slice
#   mean_L = np.nanmean(L, axis=0)
# /Users/mariiashapo/anaconda3/envs/node_25/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# <Axes: title={'center': 'Testing MSE — Pyomo vs JAX vs PyTorch'}, xlabel='Training Time (s)', ylabel='Mse Test (log scale)'>

# %%
results = load_all_pickles("results/study_vdp/pytorch_vdp_400_1000_w32", recursive=False)
pytoch_results_df_400_w32 = Results.flatten_convergence_data(results, key_list=["system", "pretrain", "max_t"], model_type="pytorch")

results = load_all_pickles("results/study_vdp/pytorch_vdp_200_1000_w32", recursive=False)
pytoch_results_df_200_w32 = Results.flatten_convergence_data(results, key_list=["system", "pretrain", "max_t"], model_type="pytorch")

results = load_all_pickles("results/study_vdp/pytorch_vdp_1000_w32", recursive=False)
pytoch_results_df_no_pretrain_32 = Results.flatten_convergence_data(results, key_list=["system", "pretrain", "max_t"], model_type="pytorch")

results = load_all_pickles("results/study_vdp/pytorch_vdp_400_1000_w64", recursive=False)
pytoch_results_df_400_w64 = Results.flatten_convergence_data(results, key_list=["system", "pretrain", "max_t"], model_type="pytorch")

results = load_all_pickles("results/study_vdp/pytorch_vdp_1000_w64", recursive=False)
pytoch_results_df_no_pretrain_64 = Results.flatten_convergence_data(results, key_list=["system", "pretrain", "max_t"], model_type="pytorch")
# Out:
# Loaded results/study_vdp/pytorch_vdp_400_1000_w32/1695354516_2025-11-05_05-25.pkl
# Loaded results/study_vdp/pytorch_vdp_400_1000_w32/2160758465_2025-11-05_07-17.pkl
# Loaded results/study_vdp/pytorch_vdp_400_1000_w32/2281306231_2025-11-05_07-01.pkl
# Loaded results/study_vdp/pytorch_vdp_400_1000_w32/238721462_2025-11-05_04-54.pkl
# Loaded results/study_vdp/pytorch_vdp_400_1000_w32/2611119799_2025-11-05_06-29.pkl
# Loaded results/study_vdp/pytorch_vdp_400_1000_w32/2775691197_2025-11-05_05-34.pkl
# Loaded results/study_vdp/pytorch_vdp_400_1000_w32/2903296063_2025-11-05_06-05.pkl
# Loaded results/study_vdp/pytorch_vdp_1000_w64/4217397791_2025-12-08_22-37.pkl
# Loaded results/study_vdp/pytorch_vdp_1000_w64/578911243_2025-12-08_22-29.pkl
# Loaded results/study_vdp/pytorch_vdp_1000_w64/749487212_2025-12-08_22-55.pkl
# Loaded results/study_vdp/pytorch_vdp_1000_w64/779056727_2025-12-08_22-33.pkl
#
# Loaded 20 files from results/study_vdp/pytorch_vdp_1000_w64

# %%
pytorch_comparison_dfs = {
    "pytorch_400_w32": pytoch_results_df_400_w32,
    "pytorch_200_w32": pytoch_results_df_200_w32,
    "pytorch_no_pretrain_w32": pytoch_results_df_no_pretrain_32,
    "pytorch_400_w64": pytoch_results_df_400_w64,
    "pytorch_no_pretrain_w64": pytoch_results_df_no_pretrain_64,
}

# %%
plot_time_bands(
    pytorch_comparison_dfs,
    y_col="mse_train",  # or "mse_test"
    title="Training MSE — Pyomo vs JAX vs PyTorch",
    logy=True,
    align_grid = False
)
# Out:
# /Users/mariiashapo/Library/CloudStorage/OneDrive-Personal/project_2324/NODE/src/utils/analyse_results.py:702: RuntimeWarning: Mean of empty slice
#   mean_L = np.nanmean(L, axis=0)
# /Users/mariiashapo/anaconda3/envs/node_25/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# <Axes: title={'center': 'Training MSE — Pyomo vs JAX vs PyTorch'}, xlabel='Training Time (s)', ylabel='Mse Train (log scale)'>

# %% [markdown]
# ### jax

# %%
results = load_all_pickles("results/study_vdp/jax_vdp_500_10000_w32", recursive=False)
jax_vdp_500_10000_w32 = Results.flatten_convergence_data(results, key_list=["system", "pretrain", "max_t"], model_type="pytorch")

results = load_all_pickles("results/study_vdp/jax_vdp_500_10000_w64", recursive=False)
jax_vdp_500_10000_w64 = Results.flatten_convergence_data(results, key_list=["system", "pretrain", "max_t"], model_type="pytorch")

results = load_all_pickles("results/study_vdp/jax_vdp_1000_10000_w32", recursive=False)
jax_vdp_1000_10000_w32 = Results.flatten_convergence_data(results, key_list=["system", "pretrain", "max_t"], model_type="pytorch")

results = load_all_pickles("results/study_vdp/jax_vdp_1000_10000_w64", recursive=False)
jax_vdp_1000_10000_w64 = Results.flatten_convergence_data(results, key_list=["system", "pretrain", "max_t"], model_type="pytorch")

results = load_all_pickles("results/study_vdp/jax_vdp_15000_w32", recursive=False)
jax_vdp_15000_w32 = Results.flatten_convergence_data(results, key_list=["system", "pretrain", "max_t"], model_type="pytorch")

results = load_all_pickles("results/study_vdp/jax_vdp_15000_w64", recursive=False)
jax_vdp_15000_w64= Results.flatten_convergence_data(results, key_list=["system", "pretrain", "max_t"], model_type="pytorch")

results = load_all_pickles("results/study_vdp/jax_vdp_1000_40000_w_reg_norm", recursive=False)
jax_vdp_10000_40000_w64= Results.flatten_convergence_data(results, key_list=["system", "pretrain", "max_t"], model_type="pytorch")

results = load_all_pickles("results/study_vdp/jax_vdp_50000_w_reg_norm", recursive=False)
jax_vdp_50000_w64= Results.flatten_convergence_data(results, key_list=["system", "pretrain", "max_t"], model_type="pytorch")
# Loaded results/study_vdp/jax_vdp_50000_w_reg_norm/690189200_2025-12-19_14-26.pkl
# Loaded results/study_vdp/jax_vdp_50000_w_reg_norm/709631830_2025-12-19_12-17.pkl
#
# Loaded 15 files from results/study_vdp/jax_vdp_50000_w_reg_norm

# %%
results = load_all_pickles("results/jax_pretrain_pyomo/jax_vdp_w2-64-2_50000_030126", recursive=False)
jax_vdp_pyomo_pretrain= Results.flatten_convergence_data(results, model_type="jax")
# Out:
# Loaded results/jax_pretrain_pyomo/jax_vdp_w2-64-2_50000_030126/1597815521_2026-01-03_20-31.pkl
# Loaded results/jax_pretrain_pyomo/jax_vdp_w2-64-2_50000_030126/2064474703_2026-01-03_17-51.pkl
# Loaded results/jax_pretrain_pyomo/jax_vdp_w2-64-2_50000_030126/2456271108_2026-01-03_17-34.pkl
# Loaded results/jax_pretrain_pyomo/jax_vdp_w2-64-2_50000_030126/2532140007_2026-01-03_19-37.pkl
# Loaded results/jax_pretrain_pyomo/jax_vdp_w2-64-2_50000_030126/2723503880_2026-01-03_19-01.pkl
# Loaded results/jax_pretrain_pyomo/jax_vdp_w2-64-2_50000_030126/284446048_2026-01-03_18-08.pkl
# Loaded results/jax_pretrain_pyomo/jax_vdp_w2-64-2_50000_030126/2863661172_2026-01-03_18-26.pkl
# Loaded results/jax_pretrain_pyomo/jax_vdp_w2-64-2_50000_030126/3237004207_2026-01-03_19-19.pkl
# Loaded results/jax_pretrain_pyomo/jax_vdp_w2-64-2_50000_030126/3607414487_2026-01-03_19-55.pkl
# Loaded results/jax_pretrain_pyomo/jax_vdp_w2-64-2_50000_030126/3976947301_2026-01-03_18-44.pkl
# Loaded results/jax_pretrain_pyomo/jax_vdp_w2-64-2_50000_030126/4090600652_2026-01-03_20-49.pkl
# Loaded results/jax_pretrain_pyomo/jax_vdp_w2-64-2_50000_030126/418252088_2026-01-03_20-13.pkl
#
# Loaded 12 files from results/jax_pretrain_pyomo/jax_vdp_w2-64-2_50000_030126

# %%
jax_comparison_dfs = {
    "jax_vdp_500_10000_w32": jax_vdp_500_10000_w32,
    "jax_vdp_500_10000_w64": jax_vdp_500_10000_w64,
    "jax_vdp_1000_10000_w32": jax_vdp_1000_10000_w32,
    "jax_vdp_1000_10000_w64": jax_vdp_1000_10000_w64,
    "jax_vdp_15000_w32": jax_vdp_15000_w32,
    "jax_vdp_15000_w64": jax_vdp_15000_w64,
    "jax_vdp_1000_40000": jax_vdp_10000_40000_w64,
    "jax_vdp_50000": jax_vdp_50000_w64,
    "jax_vdp_pyomo_pretrain": jax_vdp_pyomo_pretrain,
}

jax_comparison_B_dfs = {
    "jax_vdp_1000_40000_w64": jax_vdp_10000_40000_w64,
    "jax_vdp_pyomo_pretrain": jax_vdp_pyomo_pretrain,
    "jax_no_pretraining": jax_vdp_50000_w64,
}

# %%
plot_time_bands(
    jax_comparison_B_dfs,
    y_col="mse_test",  # or "mse_test"
    title="Training MSE — Pyomo vs JAX vs PyTorch",
    logy=True,
    align_grid = False,
    min_support_abs=1,
    xlim =(0, 30)
)
# Out:
# /Users/mariiashapo/Library/CloudStorage/OneDrive-Personal/project_2324/NODE/src/utils/analyse_results.py:702: RuntimeWarning: Mean of empty slice
#   mean_L = np.nanmean(L, axis=0)
# /Users/mariiashapo/anaconda3/envs/node_25/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# <Axes: title={'center': 'Training MSE — Pyomo vs JAX vs PyTorch'}, xlabel='Training Time (s)', ylabel='Mse Test (log scale)'>

# %%
plot_time_bands(
    jax_comparison_B_dfs,
    y_col="mse_train",  # or "mse_test"
    title="Training MSE — Pyomo vs JAX vs PyTorch",
    logy=True,
    align_grid = False,
    min_support_abs=1,
    xlim =(0, 30)
)
# Out:
# /Users/mariiashapo/Library/CloudStorage/OneDrive-Personal/project_2324/NODE/src/utils/analyse_results.py:702: RuntimeWarning: Mean of empty slice
#   mean_L = np.nanmean(L, axis=0)
# /Users/mariiashapo/anaconda3/envs/node_25/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# <Axes: title={'center': 'Training MSE — Pyomo vs JAX vs PyTorch'}, xlabel='Training Time (s)', ylabel='Mse Train (log scale)'>

# %%
results = load_all_pickles("results/jax_pretrain_pyomo_vdp_w2-64-2/jax_vdp_5000_311225", recursive=False)
# Out:
# Loaded 0 files from results/jax_pretrain_pyomo_vdp_w2-64-2/jax_vdp_5000_311225

# %%
results_df_64["pretrain"] = False

comparison_dfs_no_pretrain = {
    # "pyomo_w32": results_df_32,
    "Pyomo": results_df_64,
    "JAX": jax_vdp_50000_w64,
    "PyTorch": pytoch_results_df_no_pretrain_64,
}

comparison_dfs = {
    # "pyomo_w32": results_df_32,
    "Pyomo": results_df_64,
    "JAX": jax_vdp_10000_40000_w64,
    "PyTorch": pytoch_results_df_400_w64,
}

# %%
results_df_64
# Out:
#    system  pretrain     max_t  time_elapsed  \
# 0     vdp     False   0.01000      0.545394
# 1     vdp     False   0.04566      0.548568
# 2     vdp     False   0.15264      0.544115
# 3     vdp     False   0.33094      0.744396
# 4     vdp     False   0.58056      1.367641
# ..    ...       ...       ...           ...
# 25    vdp     False  22.29746     22.668602
# 26    vdp     False  24.11611     24.599787
# 27    vdp     False  26.00609     26.383583
# 28    vdp     False  27.96738     28.405078
# 29    vdp     False  30.00000     30.339307
#
#                                     direct_model_pred  \
# 0   [[-0.01668566971111513, -0.015491323533380287,...
# 1   [[-0.01668566971111513, -0.015491323533380287,...
# 2   [[-0.01668566971111513, -0.015491323533380287,...
# 3   [[-0.008342834855557564, -0.007228773446576301...
# 4   [[0.0, 0.0011177495076299913, 0.00303402752865...
# ..                                                ...
# 25  [[4.151050988506156e-21, 0.0005809623032916951...
# 26  [[8.196602139549097e-23, 0.0006019798880231487...
# 27  [[5.486417621650125e-22, 0.0006103906814917283...
# 28  [[2.772520077687203e-23, 0.0006110132091551477...
# 29  [[2.4467116346480477e-16, 0.000603495289292624...
#
#                                           odeint_pred  \
# 0   [[0.0, 1.0], [7.415036e-05, 1.0000563], [0.000...
# 1   [[0.0, 1.0], [7.415036e-05, 1.0000563], [0.000...
# 2   [[0.0, 1.0], [7.415036e-05, 1.0000563], [0.000...
# 3   [[0.0, 1.0], [-0.000439375, 1.0083624], [-0.00...
# 4   [[0.0, 1.0], [0.000988806, 1.0038314], [0.0039...
# ..                                                ...
# 25  [[0.0, 1.0], [0.00059546786, 1.0014875], [0.00...
# 26  [[0.0, 1.0], [0.0006043577, 1.0015802], [0.002...
# 27  [[0.0, 1.0], [0.0006135822, 1.0015749], [0.002...
# 28  [[0.0, 1.0], [0.0006146695, 1.0015719], [0.002...
# 29  [[0.0, 1.0], [0.0006087056, 1.0015622], [0.002...
#
#                                      odeint_pred_test  mse_train   mse_test  \
# 0   [[1.907251, -0.77596635], [1.9075878, -0.77564...   3.183486  18.363491
# 1   [[1.907251, -0.77596635], [1.9075878, -0.77564...   3.183486  18.363491
# 2   [[1.907251, -0.77596635], [1.9075878, -0.77564...   3.183486  18.363491
# 3   [[1.907251, -0.77596635], [1.9079899, -0.77827...  15.657300  16.266620
# 4   [[1.907251, -0.77596635], [1.9065248, -0.77715...   2.041145   2.855530
# ..                                                ...        ...        ...
# 25  [[1.907251, -0.77596635], [1.9066169, -0.77648...   0.389640   1.437330
# 26  [[1.907251, -0.77596635], [1.906617, -0.776440...   0.002992   0.826394
# 27  [[1.907251, -0.77596635], [1.9066155, -0.77644...   0.002915   0.832854
# 28  [[1.907251, -0.77596635], [1.9066149, -0.77644...   0.002959   0.863033
# 29  [[1.907251, -0.77596635], [1.9066153, -0.77644...   0.003012   0.863450
#
#       termination          seed
# 0   maxIterations  1.028514e+09
# 1   maxIterations  1.028514e+09
# 2   maxIterations  1.028514e+09
# 3   maxIterations  1.028514e+09
# 4   maxIterations  1.028514e+09
# ..            ...           ...
# 25  maxIterations  8.571416e+07
# 26  maxIterations  8.571416e+07
# 27  maxIterations  8.571416e+07
# 28  maxIterations  8.571416e+07
# 29  maxIterations  8.571416e+07
#
# [413 rows x 11 columns]

# %%
max_q_maps = {
    "Pyomo": 1.0,
    "JAX": 0.85,
    "PyTorch": 0.6,
}

# %%
plot_time_bands(
    comparison_dfs,
    y_col="mse_train",  # or "mse_test"
    title="",
    logy=True,
    align_grid = False,
    figsize=(10, 6),
    label_fontsize=16,
    tick_fontsize=13,
    legend_fontsize=13,
    title_fontsize=16,
    tmax_quantile=max_q_maps,
    xlim =(0, 60)
)
# Out:
# /Users/mariiashapo/Library/CloudStorage/OneDrive-Personal/project_2324/NODE/src/utils/analyse_results.py:702: RuntimeWarning: Mean of empty slice
#   mean_L = np.nanmean(L, axis=0)
# /Users/mariiashapo/anaconda3/envs/node_25/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# <Axes: xlabel='Training Time (s)', ylabel='Mse Train (log scale)'>

# %%
plot_time_bands(
    comparison_dfs,
    y_col="mse_test",  # or "mse_test"
    title="",
    logy=True,
    align_grid = False,
    figsize=(10, 6),
    label_fontsize=16,
    tick_fontsize=13,
    legend_fontsize=13,
    title_fontsize=16,
    xlim =(0, 60)
)
# Out:
# /Users/mariiashapo/Library/CloudStorage/OneDrive-Personal/project_2324/NODE/src/utils/analyse_results.py:702: RuntimeWarning: Mean of empty slice
#   mean_L = np.nanmean(L, axis=0)
# /Users/mariiashapo/anaconda3/envs/node_25/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# <Axes: xlabel='Training Time (s)', ylabel='Mse Test (log scale)'>

# %%
"jax_pretrain_pyomo_vdp_w2-64-2"
# Out:
# 'jax_pretrain_pyomo_vdp_w2-64-2'

# %%
results = load_all_pickles("results/jax_pretrain_pyomo_vdp_w2-64-2/jax_vdp_5000_311225", recursive=False)
# Out:
# Loaded 0 files from results/jax_pretrain_pyomo_vdp_w2-64-2/jax_vdp_5000_311225

# %%
cleaned = []
for r in results:
    if isinstance(r, dict) and "time_elapsed" in r:
        r = dict(r)
        r["time_elapsed"] = [r["time_elapsed"]]  # wrap scalar
        r["train_loss"] = [[[r.get("mse_train")],[r.get("mse_test")]]]  # minimal structure
    cleaned.append(r)
df = Results.flatten_convergence_data(cleaned, model_type="jax")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 8
#       6         r["train_loss"] = [[[r.get("mse_train")],[r.get("mse_test")]]]  # minimal structure
#       7     cleaned.append(r)
# ----> 8 df = Results.flatten_convergence_data(cleaned, model_type="jax")
#
# File ~/Library/CloudStorage/OneDrive-Personal/project_2324/NODE/src/utils/analyse_results.py:548, in Results.flatten_convergence_data(results_li, model_type, key_list)
#     545         df["seed"] = i
#     546     dfs_li.append(df)
# --> 548 full_df = pd.concat(dfs_li)
#     549 return full_df
#
# File ~/anaconda3/envs/node_25/lib/python3.9/site-packages/pandas/core/reshape/concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# File ~/anaconda3/envs/node_25/lib/python3.9/site-packages/pandas/core/reshape/concat.py:445, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     442 self.verify_integrity = verify_integrity
#     443 self.copy = copy
# --> 445 objs, keys = self._clean_keys_and_objs(objs, keys)
#     447 # figure out what our result ndim is going to be
#     448 ndims = self._get_ndims(objs)
#
# File ~/anaconda3/envs/node_25/lib/python3.9/site-packages/pandas/core/reshape/concat.py:507, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     504     objs_list = list(objs)
#     506 if len(objs_list) == 0:
# --> 507     raise ValueError("No objects to concatenate")
#     509 if keys is None:
#     510     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate

# %%
df
# Out:
#    time_elapsed  mse_train  mse_test system  pretrain max_iter  seed
# 0     46.645979   2.790652  2.971207    vdp      True   [5000]     0
