# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# jax
import jax.numpy as jnp
from jax import random
import time

# stats
from statsmodels.api import tsa # time series analysis
import statsmodels.api as sm

# interpolation
from scipy.interpolate import CubicSpline

# pre-processing
from sklearn.preprocessing import StandardScaler
import preprocess # helper preprocessing class

# collocation
import sys
import os
p_ = os.path.abspath(os.path.join('..', '00_utils'))
if p_ not in sys.path:
    sys.path.append(p_)
    
p_ = os.path.abspath(os.path.join('..', '00_models'))
if p_ not in sys.path:
    sys.path.append(p_)

from collocation import compute_weights, lagrange_derivative
from non_parametric_collocation import collocate_data

# pyomo
import importlib
import nn_pyomo_base
import nn_pyomo_base_dae

import statsmodels.api as sm
from scipy.ndimage import gaussian_filter1d

# %%
importlib.reload(preprocess)
DataPreprocessor = preprocess.DataPreprocessor

file_path = '../00_data/df_train.csv'
encoding = {'settlement_date': 't', 'temperature': 'var1', 'hour': 'var2', 'nd': 'y'}

data_loader = DataPreprocessor(file_path, start_date = '2015-01-10', number_of_points = 400, tau = 48, m = 1, feature_encoding = encoding, split=200)
data_subsample = data_loader.load_data()
df_train, df_test = data_loader.preprocess_data(data_subsample)

# %%
if True:
    plt.figure(figsize=(15, 6))
    for col in df_train.columns.difference(['t']):
        if col == 'y':
            plt.scatter(df_train['t'], df_train[col], label=col, alpha=1)
            continue
        plt.plot(df_train['t'], df_train[col], '-', label=col, alpha=0.5)
        
    for col in df_test.columns.difference(['t']):
        plt.plot(df_test['t'], df_test[col], '-', label=col, alpha=0.5)

    plt.legend()
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.title('Train Data')
    plt.grid(True)
    plt.show()

# %%
ys = np.atleast_2d(df_train['y']).T
ts = np.array(df_train['t'])
Xs = np.atleast_2d(df_train.drop(columns=['y', 't']))

w = compute_weights(df_train['t'])
Ds = np.array(lagrange_derivative(df_train['t'], w))

# %%
"""
(self, y_observed, t, first_derivative_matrix, layer_sizes, time_invariant = True, extra_input = None, 
                penalty_lambda_reg=0.1,
                act_func="tanh", w_init_method="random", params = None, y_init = None, constraint = "l1")
""";

# %%
importlib.reload(nn_pyomo_base)
NeuralODEPyomo = nn_pyomo_base.NeuralODEPyomo

tol = 1e-8
params = {"tol":tol, 
        "dual_inf_tol": tol, "compl_inf_tol": tol, "constr_viol_tol": tol, 
        "halt_on_ampl_error" : 'yes', "print_level": 5, "max_iter": 500}

layer_sizes = [7, 30, 1]

ode_model = NeuralODEPyomo(y_observed = ys, 
                        t = ts, # t
                        first_derivative_matrix = Ds, # derivative matrix
                        extra_input = Xs, # extra inputs
                        y_init = ys,
                        layer_sizes = layer_sizes, act_func = "tanh", 
                        penalty_lambda_reg = 0.01, 
                        time_invariant = True,
                        w_init_method = 'xavier', 
                        params = params
                        )

ode_model.build_model()
result = ode_model.solve_model()
u_model = ode_model.extract_solution().T
# Out:
# y
# Ipopt 3.14.16: tol=1e-08
# dual_inf_tol=1e-08
# compl_inf_tol=1e-08
# constr_viol_tol=1e-08
# halt_on_ampl_error=yes
# print_level=5
# max_iter=500
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.16, running with linear solver MUMPS 5.7.1.
#
# Number of nonzeros in equality constraint Jacobian...:    93729
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:    55281
#
# Total number of variables............................:      471
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      471
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      199
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.4565788e-01 5.15e+02 1.22e-02  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5
-01    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  110  1.7016224e+01 3.31e-01 1.04e-02  -3.8 2.34e-01  -1.1 1.00e+00 2.50e-01h  3
#  111  1.7012761e+01 1.06e-01 8.95e-03  -3.8 4.87e-02  -0.7 1.00e+00 1.00e+00h  1
#  112  1.7009095e+01 4.11e-01 1.09e-02  -3.8 1.43e-01  -1.2 1.00e+00 1.00e+00h  1
#  113  1.7007191e+01 7.07e-01 9.60e-03  -3.8 8.36e-01    -  1.00e+00 5.00e-01h  2
#  114  1.7001909e+01 1.19e-01 3.03e-03  -3.8 2.19e-01    -  1.00e+00 1.00e+00h  1
#  115  1.7001347e+01 1.30e-02 1.23e-04  -3.8 5.47e-02    -  1.00e+00 1.00e+00h  1
#  116  1.7001395e+01 3.73e-05 4.03e-07  -3.8 3.55e-03    -  1.00e+00 1.00e+00h  1
#  117  1.7001395e+01 4.00e-09 2.45e-10  -5.7 3.88e-05    -  1.00e+00 1.00e+00h  1
#  118  1.7001395e+01 1.01e-11 3.46e-14  -8.6 4.87e-07    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 118
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.7001394942111450e+01    1.7001394942111450e+01
# Dual infeasibility......:   3.4592496705323854e-14    3.4592496705323854e-14
# Constraint violation....:   2.3670148249917782e-13    1.0050238419267998e-11
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.5059993381916320e-09    2.5059993381916320e-09
# Overall NLP error.......:   2.5059993381916320e-09    2.5059993381916320e-09
#
#
# Number of objective function evaluations             = 175
# Number of objective gradient evaluations             = 119
# Number of equality constraint evaluations            = 175
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 119
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 118
# Total seconds in IPOPT                               = 5.320
#
# EXIT: Optimal Solution Found.
# {'solver_time': 5.416747093200684, 'termination_condition': <TerminationCondition.optimal: 'optimal'>, 'message': 'Ipopt 3.14.16\\x3a Optimal Solution Found'}

# %%
y0 = ys[0]
y_pred = ode_model.neural_ode(y0, ts, (Xs, ts))

plt.figure(figsize=(20, 10))
plt.plot(ts, ys, label='True Data', alpha = 1)
plt.plot(ts, u_model, label='True Data', alpha = 1)
plt.scatter(ts, y_pred, label='Model Prediction (Train) - Odeint', alpha = 0.7)

plt.legend(loc ="lower right")
plt.grid(True)
plt.show()

# %%
import ode_solver_pyomo_dae
import ode_solver_pyomo_base

# %%
trained_weights_biases = ode_model.extract_weights()

W1 = trained_weights_biases['W1']
b1 = trained_weights_biases['b1']
W2 = trained_weights_biases['W2']
b2 = trained_weights_biases['b2']

trained_weights = [W1, W2]
trained_biases = [b1, b2]

# %%
importlib.reload(ode_solver_pyomo_base)
DirectODESolver = ode_solver_pyomo_base.DirectODESolver

# Define the layer sizes as per your neural network architecture
layer_sizes = [W1.shape[1], W1.shape[0], W2.shape[0]]

tol = 1e-7
params = {"tol":1e-7, 
            "dual_inf_tol": tol, 
            "compl_inf_tol": tol,
            "constr_viol_tol": tol, 
            "acceptable_iter": 0,  
            "halt_on_ampl_error" : 'yes',
            "print_level": 5, 
            "max_iter": 100 }

initial_state = ys[0][0]
direct_solver = DirectODESolver(np.array(ts), layer_sizes, trained_weights, trained_biases, initial_state, 
                                D = Ds,
                                time_invariant=True, extra_input=np.array(Xs), params = params)

direct_solver.build_model()
solver_info = direct_solver.solve_model()
y_solution = direct_solver.extract_solution()
#t_solution, y_solution = direct_solver.extract_solution()
# Out:
# Ipopt 3.14.16: tol=1e-07
# dual_inf_tol=1e-07
# compl_inf_tol=1e-07
# constr_viol_tol=1e-07
# acceptable_iter=0
# halt_on_ampl_error=yes
# print_level=5
# max_iter=100
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.16, running with linear solver MUMPS 5.7.1.
#
# Number of nonzeros in equality constraint Jacobian...:    39801
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      199
#
# Total number of variables............................:      200
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      200
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      200
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.0000000e+00 1.71e+02 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.0000000e+00 2.18e+02 3.04e+07  -1.0 3.42e+00    -  6.00e-01 1.00e+00h  1
#    2r 1.0000000e+00 2.18e+02 9.99e+02   1.9 0.00e+00    -  0.00e+00 2.10e-07R  2
#    3r 1.0000000e+00 1.78e+02 9.98e+02   1.9 8.14e+04    -  8.60e-04 1.02e-03f  1
#    4r 1.0000000e+00 1.73e+02 9.95e+02   1.2 3.09e+04    -  3.18e-03 1.05e-03f  1
#    5r 1.0000000e+00 1.58e+02 9.64e+02   1.2 2.49e+03    -  3.10e-02 5.27e-03f  1
#    6r 1.0000000e+00 1.51e+02 8.00e+02   1.2 1.30e+02    -  3.60e-01 3.62e-02f  1
#    7r 1.0000000e+00 8.58e+01 2.82e+02   1.2 2.61e+00    -  1.00e+00 3.79e-01f  1
#    8r 1.0000000e+00 5.85e+01 4.61e+02   0.5 7.28e-01    -  1.00e+00 2.95e-01f  1
#    9r 1.0000000e+00 1.37e+01 2.86e+02   0.5 4.47e-01    -  7.08e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10r 1.0000000e+00 2.14e-01 1.82e-01   0.5 4.73e-02    -  1.00e+00 1.00e+00h  1
#   11r 1.0000000e+00 2.00e-01 1.11e+00  -1.6 2.62e-02    -  9.93e-01 9.90e-01f  1
#   12r 1.0000000e+00 2.00e-01 9.15e-05  -1.6 6.54e-04    -  1.00e+00 1.00e+00f  1
#   13r 1.0000000e+00 2.00e-01 9.75e-02  -3.5 3.09e-03    -  1.00e+00 1.00e+00f  1
#   14r 1.0000000e+00 2.00e-01 4.18e-06  -3.5 1.78e-04    -  1.00e+00 1.00e+00h  1
#   15r 1.0000000e+00 2.00e-01 9.85e-03  -5.3 2.40e-04    -  1.00e+00 1.00e+00f  1
#   16r 1.0000000e+00 2.00e-01 5.98e-08  -5.3 2.59e-05    -  1.00e+00 1.00e+00h  1
#   17r 1.0000000e+00 2.00e-01 1.41e-03  -8.0 3.33e-05    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 17
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.0000000000000000e+00    1.0000000000000000e+00
# Dual infeasibility......:   6.9752992563293782e-05    6.9752992563293782e-05
# Constraint violation....:   2.0012781389677015e-01    2.0012781389677015e-01
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   1.1004869279308121e-08    1.1004869279308121e-08
# Overall NLP error.......:   2.0012781389677015e-01    2.0012781389677015e-01
#
#
# Number of objective function evaluations             = 22
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 22
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 20
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 18
# Total seconds in IPOPT                               = 0.105
#
# EXIT: Converged to a point of local infeasibility. Problem may be infeasible.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: Ipopt 3.14.16\x3a Converged to a locally infeasible
#       point. Problem may be infeasible.
# {'solver_time': 0.15609979629516602, 'termination_condition': <TerminationCondition.infeasible: 'infeasible'>, 'message': 'Ipopt 3.14.16\\x3a Converged to a locally infeasible point. Problem may be infeasible.'}

# %%
plt.figure(figsize=(20, 10))
plt.plot(ts, ys, label='True Data', alpha = 1)
plt.plot(ts, u_model, label='True Data', alpha = 1)
plt.plot(ts, y_solution, label='Model Prediction (Train) - Odeint', alpha = 0.7)

plt.legend(loc ="lower right")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Test set

# %%
ys_test = np.atleast_2d(df_test['y']).T
ts_test = np.array(df_test['t'])
Xs_test = np.atleast_2d(df_test.drop(columns=['y', 't']))

w_test = compute_weights(df_test['t'])
Ds_test = np.array(lagrange_derivative(df_test['t'].values, w_test))

# %%
importlib.reload(ode_solver_pyomo_base)
DirectODESolver = ode_solver_pyomo_base.DirectODESolver

# Define the layer sizes as per your neural network architecture
layer_sizes = [W1.shape[1], W1.shape[0], W2.shape[0]]

tol = 1e-8
params = {"tol":tol, 
            "dual_inf_tol": tol, 
            "compl_inf_tol": tol,
            "constr_viol_tol": tol, 
            #"acceptable_iter": 0,  
            #"halt_on_ampl_error" : 'yes',
            "print_level": 5, 
            "max_iter": 1000 }

initial_state = ys_test[0][0]
direct_solver = DirectODESolver(ts_test, layer_sizes, trained_weights, trained_biases, initial_state, 
                                D = Ds_test,
                                time_invariant=True, extra_input=np.array(Xs_test), params = params)

direct_solver.build_model()
solver_info = direct_solver.solve_model()
y_solution = direct_solver.extract_solution()
# Out:
# Ipopt 3.14.16: tol=1e-08
# dual_inf_tol=1e-08
# compl_inf_tol=1e-08
# constr_viol_tol=1e-08
# print_level=5
# max_iter=1000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.16, running with linear solver MUMPS 5.7.1.
#
# Number of nonzeros in equality constraint Jacobian...:    39801
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      199
#
# Total number of variables............................:      200
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      200
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      200
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.0000000e+00 1.92e+02 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.0000000e+00 2.75e+02 2.00e+07  -1.0 3.17e+00    -  6.15e-01 1.00e+00h  1
#    2  1.0000000e+00 2.75e+02 2.00e+07  -1.0 2.04e+10    -  2.54e-10 1.20e-11f  5
#    3  1.0000000e+00 2.27e+02 7.36e+07  -1.0 4.05e+00    -  3.39e-01 1.00e+00h  1
#    4  1.0000000e+00 2.27e+02 7.36e+07  -1.0 1.81e+08    -  2.37e-08 1.54e-08f  2
#    5  1.0000000e+00 2.68e+02 7.36e+07  -1.0 1.08e+08    -  2.61e-08 1.16e-08f  3
#    6  1.0000000e+00 2.65e+02 7.36e+07  -1.0 2.59e+08    -  2.01e-08 9.80e-10f  5
#    7  1.0000000e+00 1.14e+02 3.80e+08  -1.0 3.86e+00    -  3.80e-01 1.00e+00h  1
#    8  1.0000000e+00 1.90e+02 7.13e+08  -1.0 3.44e+00    -  6.45e-01 1.00e+00h  1
#    9  1.0000000e+00 1.90e+02 7.13e+08  -1.0 1.04e+10    -  5.17e-10 1.37e-11f  6
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.0000000e+00 1.12e+02 1.64e+09  -1.0 2.55e+00    -  4.71e-01 1.00e+00h  1
#   11r 1.0000000e+00 1.12e+02 9.99e+02   1.5 0.00e+00    -  0.00e+00 2.80e-08R  2
#   12r 1.0000000e+00 1.10e+02 9.77e+02   1.5 3.42e+04    -  4.61e-01 1.01e-03f  1
#   13r 1.0000000e+00 3.83e+01 6.80e+02   1.5 3.76e+01    -  3.42e-02 2.94e-01f  1
#   14r 1.0000000e+00 3.53e+01 3.57e+02   0.8 6.55e+00    -  1.00e+00 3.27e-01f  1
#   15r 1.0000000e+00 1.54e+01 1.43e+02   0.8 9.91e-01    -  1.00e+00 5.68e-01f  1
#   16r 1.0000000e+00 1.40e+01 1.62e+03   0.8 4.29e-01    -  9.23e-01 9.19e-02f  1
#   17r 1.0000000e+00 8.26e-01 1.64e+01   0.8 3.89e-01    -  1.00e+00 1.00e+00f  1
#   18r 1.0000000e+00 3.25e-01 3.02e+00  -0.6 9.64e-03    -  1.00e+00 1.00e+00f  1
#   19r 1.0000000e+00 3.25e-01 4.18e-01  -1.3 1.21e-03    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20r 1.0000000e+00 3.25e-01 2.89e-01  -2.9 5.12e-04    -  1.00e+00 1.00e+00f  1
#   21r 1.0000000e+00 3.25e-01 2.03e-08  -2.9 1.37e-04    -  1.00e+00 1.00e+00h  1
#   22r 1.0000000e+00 3.25e-01 4.85e-02  -6.6 1.67e-04    -  1.00e+00 1.00e+00f  1
#   23r 1.0000000e+00 3.25e-01 1.07e-10  -6.6 4.30e-06    -  1.00e+00 1.00e+00h  1
#   24r 1.0000000e+00 3.25e-01 6.87e-04  -9.0 2.42e-06    -  1.00e+00 1.00e+00f  1
#   25r 1.0000000e+00 3.25e-01 1.25e-11  -9.0 3.56e-05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 25
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.0000000000000000e+00    1.0000000000000000e+00
# Dual infeasibility......:   4.3039056201024018e-05    4.3039056201024018e-05
# Constraint violation....:   3.2463937788794750e-01    3.2463937788794750e-01
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.0909090909090931e-10    9.0909090909090931e-10
# Overall NLP error.......:   3.2463937788794750e-01    3.2463937788794750e-01
#
#
# Number of objective function evaluations             = 51
# Number of objective gradient evaluations             = 13
# Number of equality constraint evaluations            = 51
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 28
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 26
# Total seconds in IPOPT                               = 0.152
#
# EXIT: Converged to a point of local infeasibility. Problem may be infeasible.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: Ipopt 3.14.16\x3a Converged to a locally infeasible
#       point. Problem may be infeasible.
# {'solver_time': 0.21879982948303223, 'termination_condition': <TerminationCondition.infeasible: 'infeasible'>, 'message': 'Ipopt 3.14.16\\x3a Converged to a locally infeasible point. Problem may be infeasible.'}

# %%
ode_model.check_violated_constraints()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[217], line 1
# ----> 1 ode_model.check_violated_constraints()
#
# AttributeError: 'NeuralODEPyomo' object has no attribute 'check_violated_constraints'

# %%
violated_constraints = []
for constr_name, constr_obj in ode_model.model.component_objects(Constraint, active=True):
    print(f"Checking constraint: {constr_name}")
    # Iterate over all indices (if the constraint is indexed)
    for index in constr_obj:
        constr = constr_obj[index]
        if constr.body() is not None:  # Ensure there is a body expression
            if not constr.lower is None and value(constr.body()) < value(constr.lower):
                violated_constraints.append((constr_name, index, "lower", value(constr.body()), value(constr.lower)))
            if not constr.upper is None and value(constr.body()) > value(constr.upper):
                violated_constraints.append((constr_name, index, "upper", value(constr.body()), value(constr.upper)))

if violated_constraints:
    print("\nViolated Constraints:")
    for v_constr in violated_constraints:
        constr_name, index, bound_type, body_val, bound_val = v_constr
        print(f"Constraint: {constr_name}[{index}] - {bound_type} bound violated")
        print(f"Value: {body_val} vs. Bound: {bound_val}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[210], line 2
#       1 violated_constraints = []
# ----> 2 for constr_name, constr_obj in ode_model.model.component_objects(Constraint, active=True):
#       3     print(f"Checking constraint: {constr_name}")
#       4     # Iterate over all indices (if the constraint is indexed)
#
# ValueError: too many values to unpack (expected 2)

# %%
plt.figure(figsize=(20, 10))
#plt.plot(ts, ys, label='True Data', alpha = 1)
#plt.plot(ts, u_model, label='True Data', alpha = 1)
plt.plot(ts_test, ys_test)
plt.plot(ts_test, y_solution, label='Model Prediction (Train) - Odeint', alpha = 0.7)

plt.legend(loc ="lower right")
plt.grid(True)
plt.show()
