# %%
import numpy as np

import jax
import jax.numpy as jnp

# -------------- helper libraries -------------- #
import sys
import os
import time
import pickle
import matplotlib.pyplot as plt
import pandas as pd
import importlib

path_ = os.path.abspath(os.path.join('..', '00_utils'))

# Add the directory to sys.path
if path_ not in sys.path:
    sys.path.append(path_)

path_ = os.path.abspath(os.path.join('..', '00_models'))

# Add the directory to sys.path
if path_ not in sys.path:
    sys.path.append(path_)

from collocation import compute_weights, lagrange_derivative
from interpolation import BarycentricInterpolation
from data_generation import generate_ode_data
from non_parametric_collocation import collocate_data
import nn_pyomo_base

# %% [markdown]
# ## Data Generation - Equally Spaced

# %%
#---------------------------------------------DATA PARAMS---------------------------------------------#
N = 200
noise_level = 0.2
ode_type, params = "harmonic_oscillator", {"omega_squared": 2}
start_time, end_time = 0, 10
spacing_type = "equally_spaced" # "equally_spaced" or "chebyshev"
initial_state = np.array([0.0, 1.0])

#--------------------------------------------GENERATE DATA--------------------------------------------#
t_ho, y_ho, y_noisy_ho, true_derivatives_ho = generate_ode_data(N, noise_level, ode_type, params, start_time, end_time, spacing_type, initial_state)

# numpy array is required for pyomo
y_noisy_ho = np.array(jnp.squeeze(y_noisy_ho))
t_ho = np.array(jnp.squeeze(t_ho))

#-----------------------------------------COLLOCATION MATRIX PREPARATION-------------------------------------------#
#weights_ho = compute_weights(t_ho)
#D_ho = np.array(lagrange_derivative(t_ho, weights_ho))

#---------------------------------------------------TEST DATA--------------------------------------------#
t_test_ho, y_test_ho, _, _ = generate_ode_data(N*2, noise_level, ode_type, params, start_time, end_time*2, "uniform", initial_state)

#--------------------------------------------NON-PARAMETRIC COLLOCATION--------------------------------------------#
estimated_derivative_ho, estimated_solution_ho = collocate_data(y_noisy_ho, t_ho, 'EpanechnikovKernel', bandwidth=0.5)
# Out:
# /Users/mariiashapo/Library/CloudStorage/OneDrive-Personal/project_2324/NODE/00_utils/non_parametric_collocation.py:95: UserWarning: Data transposed to match expected dimensions.
#   warnings.warn("Data transposed to match expected dimensions.")

# %% [markdown]
# ### Pyomo, continuous, equally spaces

# %%
import nn_pyomo_continious
importlib.reload(nn_pyomo_continious)
NeuralODEPyomo_cont = nn_pyomo_continious.NeuralODEPyomo

layer_widths = [2, 20, 2]

# solver.options['print_level'] = 5
tol = 1e-2
params = {"tol":1e-2, 
          "dual_inf_tol": tol, 
          "compl_inf_tol": tol,
          "constr_viol_tol": tol, 
          
          # repeat the same for the acceptable tolerances
          "acceptable_tol": 1e-15,
          "acceptable_constr_viol_tol": 1e-15,
          "acceptable_dual_inf_tol": 1e-15,
          "acceptable_compl_inf_tol": 1e-15,
          "acceptable_iter": 0, 
          
          "halt_on_ampl_error" : 'yes',
          "print_level": 5, 
          #"hessian_approximation": 'limited-memory', 
          #"mu_strategy": 'adaptive', 
          #"check_derivatives_for_naninf": 'yes',
          "max_iter": 1000}

y0 = np.array([0.0, 1.0])
solver_time = 0
mae_train, mae_test = 0, 0

for i in range(10):
    start_timer_build = time.time()
    ode_model = NeuralODEPyomo_cont(np.array(y_noisy_ho), # y
                            np.array(t_ho), # t
                            np.array(None),
                            
                            layer_widths, act_func = "tanh", 
                            y_init = np.array(estimated_solution_ho), 
                            penalty_lambda_reg = 0.1, 
                            time_invariant = True,
                            # extra_input 
                            w_init_method = 'xavier', 
                            params = params,
                            deriv_method = "pyomo",
                            is_continuous = True
                            )

    ode_model.build_model()
    result = ode_model.solve_model()
    u_model = ode_model.extract_solution()
    solver_time += result['solver_time']
    
    y_pred = ode_model.neural_ode(y0, t_ho)
    y1 = y_test_ho[-1]
    y_pred_test = ode_model.neural_ode(y0, t_test_ho)
    
    mae_train += np.mean(np.abs(y_ho - y_pred))
    mae_test += np.mean(np.abs(y_test_ho - y_pred_test))
# Out:
# Ipopt 3.14.16: tol=0.01
# dual_inf_tol=0.01
# compl_inf_tol=0.01
# constr_viol_tol=0.01
# acceptable_tol=1e-15
# acceptable_constr_viol_tol=1e-15
# acceptable_dual_inf_tol=1e-15
# acceptable_compl_inf_tol=1e-15
# acceptable_iter=0
# halt_on_ampl_error=yes
# print_level=5
# max_iter=1000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.16, running with linear solver MUMPS 5.7.1.
#
# Number of nonzeros in equality constraint Jacobian...:   106266
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:   121475
#
# Total number of variables............................:     2492
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:     1298
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     2388
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.4861294e+01 4.09e+00 1.42e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.4856980e+01 1.09e+00 1.79e-01  -1.0 1.65e+00    -  9.82e-01 1.00e+00h  1
#    2  1.5392694e+01 1.82e-01 1.07e+00  -1.0 3.78e-01   0.0 1.00e+00 1.00e+00h  1
#    3  1.5207769e+01 1.63e-02 4.38e-01  -1.0 1.27e-01   0.4 1.00e+00 1.00e+00h  1
#    4  1.5188502e+01 2.06e-04 9.83e-02  -1.7 1.05e-02   0.9 1.00e+00 1.00e+00h  1
#    5  1.5154920e+01 3.83e-04 3.40e-02  -2.5 1.35e-02   0.4 1.00e+00 1.00e+00h  1
#    6  1.5092456e+01 1.72e-03 2.45e-02  -2.5 3.11e-02  -0.1 1.00e+00 1.00e+00h  1
#    7  1.5031968e+01 4.42e-03 1.47e-02  -3.0 5.63e-02  -0.6 1.00e+00 1.00e+00h  1
#    8  1.5013741e+01 6.69e-03 5.09e-03  -3.0 5.59e-02  -1.1 1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 8
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.5013740725812015e+01    1.5013740725812015e+01
# Dual infeasibility......:   5.0945294049475343e-03    5.0945294049475343e-03
# Constraint violation....:   6.6919173786547104e-03    6.6919173786547104e-03
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.0910003266837694e-04    9.0910003266837694e-04
# Overall NLP error.......:   6.6919173786547104e-03    6.6919173786547104e-03
#
#
# Number of objective function evaluations             = 9
# Number of objective gradient evaluations             = 9
# Number of equality constraint evaluations            = 9
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 9
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 8
# Total seconds in IPOPT                               = 2.555
#
# EXIT: Optimal Solution Found.
# {'solver_time': 2.651724100112915, 'termination_condition': <TerminationCondition.optimal: 'optimal'>, 'message': 'Ipopt 3.14.16\\x3a Optimal Solution Found'}
# Ipopt 3.14.16: tol=0.01
# dual_inf_tol=0.01
# compl_inf_tol=0.01
# constr_viol_tol=0.01
# acceptable_tol=1e-15
# acceptable_constr_viol_tol=1e-15
# acceptable_dual_inf_tol=1e-15
# acceptable_compl_inf_tol=1e-15
# acceptable_iter=0
# halt_on_ampl_error=yes
# print_level=5
# max_iter=1000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.16, running with linear solver MUMPS 5.7.1.
#
# Number of nonzeros in equality constraint Jacobian...:   106266
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:   121475
#
# Total number of variables............................:     2492
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:     1298
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     2388
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.4692027e+01 4.09e+00 1.58e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 49
#      33 ode_model = NeuralODEPyomo_cont(np.array(y_noisy_ho), # y
#      34                         np.array(t_ho), # t
#      35                         np.array(None),
#    (...)
#      45                         is_continuous = True
#      46                         )
#      48 ode_model.build_model()
# ---> 49 result = ode_model.solve_model()
#      50 u_model = ode_model.extract_solution()
#      51 solver_time += result['solver_time']
#
# File ~/Library/CloudStorage/OneDrive-Personal/project_2324/NODE/01_neural_nets_2d_comparisons/nn_pyomo_continious.py:334, in NeuralODEPyomo.solve_model(self)
#     332     for key, value in self.params.items():
#     333         solver.options[key] = value
# --> 334 result = solver.solve(self.model, tee=True)
#     336 # Extract solver information
#     337 solver_time = result.solver.time
#
# File ~/anaconda3/envs/collocation_env/lib/python3.9/site-packages/pyomo/opt/base/solvers.py:610, in OptSolver.solve(self, *args, **kwds)
#     607 if not _model is None:
#     608     self._initialize_callbacks(_model)
# --> 610 _status = self._apply_solver()
#     611 if hasattr(self, '_transformation_data'):
#     612     del self._transformation_data
#
# File ~/anaconda3/envs/collocation_env/lib/python3.9/site-packages/pyomo/opt/solver/shellcmd.py:266, in SystemCallSolver._apply_solver(self)
#     263         print("Solver problem files: %s" % str(self._problem_files))
#     265 sys.stdout.flush()
# --> 266 self._rc, self._log = self._execute_command(self._command)
#     267 sys.stdout.flush()
#     268 return Bunch(rc=self._rc, log=self._log)
#
# File ~/anaconda3/envs/collocation_env/lib/python3.9/site-packages/pyomo/opt/solver/shellcmd.py:334, in SystemCallSolver._execute_command(self, command)
#     332 try:
#     333     with TeeStream(*ostreams) as t:
# --> 334         results = subprocess.run(
#     335             command.cmd,
#     336             input=_input,
#     337             env=command.env,
#     338             stdout=t.STDOUT,
#     339             stderr=t.STDERR,
#     340             timeout=timeout,
#     341             universal_newlines=True,
#     342             cwd=command.cwd if "cwd" in command else None,
#     343         )
#     344         t.STDOUT.flush()
#     345         t.STDERR.flush()
#
# File ~/anaconda3/envs/collocation_env/lib/python3.9/subprocess.py:507, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     505 with Popen(*popenargs, **kwargs) as process:
#     506     try:
# --> 507         stdout, stderr = process.communicate(input, timeout=timeout)
#     508     except TimeoutExpired as exc:
#     509         process.kill()
#
# File ~/anaconda3/envs/collocation_env/lib/python3.9/subprocess.py:1126, in Popen.communicate(self, input, timeout)
#    1124         stderr = self.stderr.read()
#    1125         self.stderr.close()
# -> 1126     self.wait()
#    1127 else:
#    1128     if timeout is not None:
#
# File ~/anaconda3/envs/collocation_env/lib/python3.9/subprocess.py:1189, in Popen.wait(self, timeout)
#    1187     endtime = _time() + timeout
#    1188 try:
# -> 1189     return self._wait(timeout=timeout)
#    1190 except KeyboardInterrupt:
#    1191     # https://bugs.python.org/issue25942
#    1192     # The first keyboard interrupt waits briefly for the child to
#    1193     # exit under the common assumption that it also received the ^C
#    1194     # generated SIGINT and will exit rapidly.
#    1195     if timeout is not None:
#
# File ~/anaconda3/envs/collocation_env/lib/python3.9/subprocess.py:1933, in Popen._wait(self, timeout)
#    1931 if self.returncode is not None:
#    1932     break  # Another thread waited.
# -> 1933 (pid, sts) = self._try_wait(0)
#    1934 # Check the pid and loop as waitpid has been known to
#    1935 # return 0 even without WNOHANG in odd situations.
#    1936 # http://bugs.python.org/issue14396.
#    1937 if pid == self.pid:
#
# File ~/anaconda3/envs/collocation_env/lib/python3.9/subprocess.py:1891, in Popen._try_wait(self, wait_flags)
#    1889 """All callers to this function MUST hold self._waitpid_lock."""
#    1890 try:
# -> 1891     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1892 except ChildProcessError:
#    1893     # This happens if SIGCLD is set to be ignored or waiting
#    1894     # for child processes has otherwise been disabled for our
#    1895     # process.  This child is dead, we can't get the status.
#    1896     pid = self.pid
#
# KeyboardInterrupt:

# %%
print(f"Average time elpased: {solver_time/10:.3f}")
print(f"Average mae_train: {mae_train/10:.3f}")
print(f"Average mae_test: {mae_test/10:.3f}")
# Out:
# Average time elpased: 5.128
# Average mae_train: 0.020
# Average mae_test: 0.021

# %%
y0 = np.array([0.0, 1.0])
y_pred = ode_model.neural_ode(y0, t_ho)
y1 = y_test_ho[-1]
y_pred_test = ode_model.neural_ode(y0, t_test_ho)

print(f"Mean Absolute Error - Direct: {np.mean(np.abs(y_noisy_ho.T - u_model))}")
print(f"Mean Absolute Error - ODE solver: {np.mean(np.abs(y_noisy_ho - y_pred))}")

#y0_test = y_test_scaled[0]
#y_pred_test = ode_model.neural_ode(y0_test, ts_test, (Xs_test, ts_test))

plt.figure(figsize=(20, 10))
plt.plot(t_ho, y_ho, label='True Data', alpha = 1)

plt.plot(t_ho, u_model[0], label='Model Prediction - Direct', alpha = 0.75)
plt.scatter(t_ho, y_pred[:,0], label='Model Prediction (Train) - Odeint')
plt.plot(t_ho, u_model[1], label='Model Prediction - Direct', alpha = 0.75)
plt.scatter(t_ho, y_pred[:,1], label='Model Prediction (Train) - Odeint')

plt.plot(t_test_ho, y_test_ho[:,0], label='Model Prediction (Test) - True Data', alpha = 0.6)
plt.plot(t_test_ho, y_test_ho[:,1], alpha = 0.6)
plt.scatter(t_test_ho, y_pred_test[:,0], label='Model Prediction (Test) - Odeint', alpha = 0.6)
plt.scatter(t_test_ho, y_pred_test[:,1], alpha = 0.6)
plt.legend(loc ="lower right")
plt.grid(True)
plt.show()
# Out:
# Mean Absolute Error - Direct: 0.15196313652740862
# Mean Absolute Error - ODE solver: 0.1541199742131654

# %% [markdown]
# ## Data Generation - Chebyshev Spacing

# %%
#---------------------------------------------DATA PARAMS---------------------------------------------#
N = 200
noise_level = 0.2
ode_type, params = "harmonic_oscillator", {"omega_squared": 2}
start_time, end_time = 0, 10
spacing_type = "chebyshev" # "equally_spaced" or "chebyshev"
initial_state = jnp.array([0.0, 1.0])

#--------------------------------------------GENERATE DATA--------------------------------------------#
t_ho_cheb, y_ho_cheb, y_noisy_ho_cheb, true_derivatives_ho_cheb = generate_ode_data(N, noise_level, ode_type, params, start_time, end_time, spacing_type, initial_state)

# numpy array is required for pyomo
y_noisy_ho_cheb = np.array(jnp.squeeze(y_noisy_ho_cheb))
t_ho_cheb = np.array(jnp.squeeze(t_ho_cheb))

#-----------------------------------------COLLOCATION MATRIX PREPARATION-------------------------------------------#
weights_ho_cheb = compute_weights(t_ho_cheb)
D_ho_cheb = np.array(lagrange_derivative(t_ho_cheb, weights_ho_cheb))

#---------------------------------------------------TEST DATA--------------------------------------------#
t_test_ho_cheb, y_test_ho_cheb, _, _ = generate_ode_data(N*2, noise_level, ode_type, params, start_time, 20, "uniform", initial_state)

#--------------------------------------------NON-PARAMETRIC COLLOCATION--------------------------------------------#
estimated_derivative_ho_cheb, estimated_solution_ho_cheb = collocate_data(y_noisy_ho_cheb, t_ho_cheb, 'EpanechnikovKernel', bandwidth=0.5)
# Out:
# /Users/mariiashapo/Library/CloudStorage/OneDrive-Personal/project_2324/NODE/00_utils/non_parametric_collocation.py:95: UserWarning: Data transposed to match expected dimensions.
#   warnings.warn("Data transposed to match expected dimensions.")

# %%
"""dy_dt_0 = []
dy_dt_1 = []

for i in range(len(derivatives)):
    dy_dt_0.append(jnp.dot(D_ho_cheb[i], y_ho[:,0]).item())
    dy_dt_1.append(jnp.dot(D_ho_cheb[i], y_ho[:,1]).item())""";

# %% [markdown]
# ### Pyomo base - discrete

# %%
import nn_pyomo_base
importlib.reload(nn_pyomo_base)
NeuralODEPyomo_base = nn_pyomo_base.NeuralODEPyomo

# %%
layer_widths = [2, 32, 2]

# solver.options['print_level'] = 5
tol = 1e-8
params = {"tol":1e-8, 
          "dual_inf_tol": tol, 
          "compl_inf_tol": tol,
          "constr_viol_tol": tol, 
          
          # repeat the same for the acceptable tolerances
          "acceptable_tol": 1e-15,
          "acceptable_constr_viol_tol": 1e-15,
          "acceptable_dual_inf_tol": 1e-15,
          "acceptable_compl_inf_tol": 1e-15,
          "acceptable_iter": 0, 
          
          "halt_on_ampl_error" : 'yes',
          "print_level": 5, 
          #"hessian_approximation": 'limited-memory', 
          #"mu_strategy": 'adaptive', 
          #"check_derivatives_for_naninf": 'yes',
          "max_iter": 500}

y0 = np.array([0.0, 1.0])
solver_time = 0
mae_train, mae_test = 0, 0

start_timer_build = time.time()
ode_model = NeuralODEPyomo_base(
                        np.array(y_noisy_ho_cheb), # y
                        np.array(t_ho_cheb), # t
                        np.array(D_ho_cheb),
                        
                        layer_widths, act_func = "tanh", 
                        y_init = np.array(estimated_solution_ho_cheb), 
                        penalty_lambda_reg = 0.0001, 
                        time_invariant = True,
                        # extra_input 
                        w_init_method = 'xavier', 
                        params = params,
                        constraint="l1", 
                        reg_norm = False
                        )

ode_model.build_model()
end_timer_build = time.time()
result = ode_model.solve_model()
u_model = ode_model.extract_solution()
solver_time += result['solver_time']

y_pred = ode_model.neural_ode(y0, t_ho_cheb)
y1 = y_test_ho_cheb[-1]
y_pred_test = ode_model.neural_ode(y0, t_test_ho_cheb)

mae_train += np.mean(np.abs(y_ho_cheb - y_pred))
mae_test += np.mean(np.abs(y_test_ho_cheb - y_pred_test))
# Out:
# current_14_08
# /Users/mariiashapo/Library/CloudStorage/OneDrive-Personal/project_2324/NODE/00_models/nn_pyomo_base.py:85: UserWarning: y_init should be structured such that each row represents a new time point.
#   warnings.warn("y_init should be structured such that each row represents a new time point.")
# Ipopt 3.14.16: tol=1e-08
# dual_inf_tol=1e-08
# compl_inf_tol=1e-08
# constr_viol_tol=1e-08
# acceptable_tol=1e-15
# acceptable_constr_viol_tol=1e-15
# acceptable_dual_inf_tol=1e-15
# acceptable_compl_inf_tol=1e-15
# acceptable_iter=0
# halt_on_ampl_error=yes
# print_level=5
# max_iter=500
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.16, running with linear solver MUMPS 5.7.1.
#
# Number of nonzeros in equality constraint Jacobian...:   131342
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:    64729
#
# Total number of variables............................:      562
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      562
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      400
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  6.8845678e-02 1.62e+00 4.43e-04  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  7.9959842e-02 3.22e-01 2.41e-01  -1.0 5.59e-01    -  9.83e-01 1.00e+00h  1
#    2  8.0106176e-02 2.64e-02 1.88e-01  -1.0 1.07e-01   0.0 1.00e+00 1.00e+00h  1
#    3  8.0080374e-02 4.09e-04 6.74e-02  -2.5 2.42e-02   0.4 1.00e+00 1.00e+00h  1
#    4  8.0003230e-02 1.08e-06 1.23e-03  -2.5 9.80e-04  -0.1 1.00e+00 1.00e+00h  1
#    5  7.9738281e-02 8.67e-06 8.81e-04  -3.8 2.97e-03  -0.5 1.00e+00 1.00e+00h  1
#    6  7.9054229e-02 6.63e-05 8.05e-04  -5.7 8.15e-03  -1.0 1.00e+00 1.00e+00h  1
#    7  7.7724896e-02 3.82e-04 6.19e-04  -5.7 1.88e-02  -1.5 1.00e+00 1.00e+00h  1
#    8  7.6307358e-02 2.06e-03 4.97e-04  -5.7 4.60e-02  -2.0 1.00e+00 1.00e+00h  1
#    9  7.5663884e-02 1.08e-02 3.57e-04  -5.7 1.05e-01  -2.4 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  7.5565687e-02 4.36e-01 6.21e-04  -5.7 8.39e-01  -2.9 1.00e+00 1.00e+00h  1
#   11  7.5262837e-02 1.20e-01 1.57e-03  -5.7 3.44e-01  -2.5 1.00e+00 1.00e+00h  1
#   12  7.5028760e-02 5.96e-02 2.78e-04  -5.7 1.86e-01  -3.0 1.00e+00 1.00e+00h  1
#   13  7.4960820e-02 2.61e-02 5.17e-05  -5.7 1.57e-01  -3.4 1.00e+00 1.00e+00h  1
#   14  7.4945194e-02 4.54e-02 6.86e-05  -5.7 2.83e+00  -3.9 1.00e+00 6.25e-02h  5
#   15  7.4923255e-02 6.92e-02 1.09e-04  -5.7 1.03e+00  -4.4 1.00e+00 2.50e-01h  3
#   16  7.4838503e-02 3.66e-02 2.48e-05  -5.7 9.48e-02  -4.0 1.00e+00 1.00e+00h  1
#   17  7.4837282e-02 2.78e-02 1.88e-05  -5.7 5.96e-02  -4.4 1.00e+00 1.00e+00h  1
#   18  7.4830770e-02 3.49e-03 2.79e-06  -5.7 2.85e-02  -4.0 1.00e+00 1.00e+00h  1
#   19  7.4828549e-02 6.62e-04 1.57e-05  -5.7 5.20e-02  -4.5 1.00e+00 1.00e+00H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  7.4828523e-02 7.59e-04 1.56e-05  -5.7 7.59e-01  -5.0 1.00e+00 1.56e-02h  7
#   21  7.4827312e-02 3.65e-04 1.16e-05  -5.7 5.08e-02  -4.5 1.00e+00 1.00e+00H  1
#   22  7.4827291e-02 6.69e-04 1.16e-05  -5.7 5.59e-01    -  1.00e+00 3.12e-02h  6
#   23  7.4828474e-02 2.14e-04 1.11e-04  -5.7 2.26e-01    -  1.00e+00 1.00e+00H  1
#   24  7.4826236e-02 9.34e-05 5.67e-06  -5.7 6.00e-02    -  1.00e+00 1.00e+00H  1
#   25  7.4826217e-02 3.36e-05 2.46e-06  -5.7 5.55e-02    -  1.00e+00 1.00e+00H  1
#   26  7.4826208e-02 2.96e-08 8.07e-08  -5.7 9.92e-03    -  1.00e+00 1.00e+00H  1
#   27  7.4826208e-02 3.08e-07 2.94e-10  -8.6 6.30e-04    -  1.00e+00 1.00e+00h  1
#   28  7.4826208e-02 4.36e-12 4.14e-15  -8.6 2.35e-06    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 28
#
#                                    (scaled)                 (unscaled)
# Objective...............:   7.4826207971769060e-02    7.4826207971769060e-02
# Dual infeasibility......:   4.1384890287105068e-15    4.1384890287105068e-15
# Constraint violation....:   4.3595127507956022e-12    4.3595127507956022e-12
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.5059035599540132e-09    2.5059035599540132e-09
# Overall NLP error.......:   2.5059035599540132e-09    2.5059035599540132e-09
#
#
# Number of objective function evaluations             = 63
# Number of objective gradient evaluations             = 29
# Number of equality constraint evaluations            = 63
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 29
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 28
# Total seconds in IPOPT                               = 3.280
#
# EXIT: Optimal Solution Found.

# %%
print(f"Average time elpased: {solver_time:.3f}")
print(f"Average mae_train: {mae_train:.3f}")
print(f"Average mae_test: {mae_test:.3f}")
# Out:
# Average time elpased: 3.390
# Average mae_train: 0.029
# Average mae_test: 0.027

# %%
y0 = np.array([0.0, 1.0])
y_pred = ode_model.neural_ode(y0, t_ho_cheb)
y1 = y_test_ho_cheb[-1]
y_pred_test = ode_model.neural_ode(y0, t_test_ho_cheb)

print(f"Mean Absolute Error - Direct: {np.mean(np.abs(y_noisy_ho_cheb.T - u_model))}")
print(f"Mean Absolute Error - ODE solver: {np.mean(np.abs(y_noisy_ho_cheb - y_pred))}")

#y0_test = y_test_scaled[0]
#y_pred_test = ode_model.neural_ode(y0_test, ts_test, (Xs_test, ts_test))

plt.figure(figsize=(20, 10))
plt.plot(t_ho_cheb, y_ho_cheb, label='True Data', alpha = 1)

plt.plot(t_ho_cheb, u_model[0], label='Model Prediction - Direct', alpha = 0.75)
plt.scatter(t_ho_cheb, y_pred[:,0], label='Model Prediction (Train) - Odeint')
plt.plot(t_ho_cheb, u_model[1], label='Model Prediction - Direct', alpha = 0.75)
plt.scatter(t_ho_cheb, y_pred[:,1], label='Model Prediction (Train) - Odeint')

plt.plot(t_test_ho_cheb, y_test_ho_cheb[:,0], label='Model Prediction (Test) - True Data', alpha = 0.6)
plt.plot(t_test_ho_cheb, y_test_ho_cheb[:,1], alpha = 0.6)
plt.scatter(t_test_ho_cheb, y_pred_test[:,0], label='Model Prediction (Test) - Odeint', alpha = 0.6)
plt.scatter(t_test_ho_cheb, y_pred_test[:,1], alpha = 0.6)
plt.legend(loc ="lower right")
plt.grid(True)
plt.show()
# Out:
# Mean Absolute Error - Direct: 0.15421744805791696
# Mean Absolute Error - ODE solver: 0.15322867315095767

# %% [markdown]
# ---
# ---

# %%
import nn_pyomo_continious
importlib.reload(nn_pyomo_continious)
NeuralODEPyomo_cont = nn_pyomo_continious.NeuralODEPyomo

layer_widths = [2, 20, 2]

# solver.options['print_level'] = 5
tol = 1e-2
params = {"tol":1e-2, 
          "dual_inf_tol": tol, 
          "compl_inf_tol": tol,
          "constr_viol_tol": tol, 
          
          # repeat the same for the acceptable tolerances
          "acceptable_tol": 1e-15,
          "acceptable_constr_viol_tol": 1e-15,
          "acceptable_dual_inf_tol": 1e-15,
          "acceptable_compl_inf_tol": 1e-15,
          "acceptable_iter": 0, 
          
          "halt_on_ampl_error" : 'yes',
          "print_level": 5, 
          #"hessian_approximation": 'limited-memory', 
          #"mu_strategy": 'adaptive', 
          #"check_derivatives_for_naninf": 'yes',
          "max_iter": 1000}

y0 = np.array([0.0, 1.0])
solver_time = 0
mae_train, mae_test = 0, 0

for i in range(10):
    start_timer_build = time.time()
    ode_model = NeuralODEPyomo_cont(np.array(y_noisy_ho_cheb), # y
                            np.array(t_ho_cheb), # t
                            np.array(None),
                            
                            layer_widths, act_func = "tanh", 
                            y_init = np.array(estimated_solution_ho_cheb), 
                            penalty_lambda_reg = 0.1, 
                            time_invariant = True,
                            # extra_input 
                            w_init_method = 'xavier', 
                            params = params,
                            deriv_method = "pyomo",
                            is_continuous = True
                            )

    ode_model.build_model()
    end_timer_build = time.time()
    result = ode_model.solve_model()
    u_model = ode_model.extract_solution()
    solver_time += result['solver_time']
    
    y_pred = ode_model.neural_ode(y0, t_ho)
    y1 = y_test_ho[-1]
    y_pred_test = ode_model.neural_ode(y0, t_test_ho)
    
    mae_train += np.mean(np.abs(y_ho - y_pred))
    mae_test += np.mean(np.abs(y_test_ho - y_pred_test))
# Out:
# Ipopt 3.14.16: tol=0.01
# dual_inf_tol=0.01
# compl_inf_tol=0.01
# constr_viol_tol=0.01
# acceptable_tol=1e-15
# acceptable_constr_viol_tol=1e-15
# acceptable_dual_inf_tol=1e-15
# acceptable_compl_inf_tol=1e-15
# acceptable_iter=0
# halt_on_ampl_error=yes
# print_level=5
# max_iter=1000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.16, running with linear solver MUMPS 5.7.1.
#
# Number of nonzeros in equality constraint Jacobian...:   106266
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:   121475
#
# Total number of variables............................:     2492
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:     1298
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     2388
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.4411723e+01 3.92e+00 1.41e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.5633119e+01 2.78e+00 1.65e+00  -1.0 1.54e+00    -  9.69e-01 1.00e+00h  1
#    2  1.7432968e+01 9.76e-01 1.30e+03  -1.0 7.99e-01   2.0 1.00e+00 1.00e+00h  1
#    3  1.6154427e+01 1.18e+00 7.26e+03  -1.0 1.79e+00   3.3 1.00e+00 5.00e-01h  2
#    4  1.6099110e+01 1.85e-01 5.86e+04  -1.0 3.63e-01   4.7 1.00e+00 1.00e+00h  1
#    5  1.5973803e+01 5.33e-02 6.40e+04  -1.0 2.05e-01   5.1 1.00e+00 1.00e+00h  1
#    6  1.5991686e+01 1.33e-03 1.67e+04  -1.0 4.62e-02   5.5 1.00e+00 1.00e+00h  1
#    7  1.5991332e+01 3.97e-06 1.37e+02  -1.0 2.10e-03   5.0 1.00e+00 1.00e+00h  1
#    8  1.5991323e+01 2.95e-11 2.27e-01  -1.0 6.21e-06   4.6 1.00e+00 1.00e+00h  1
#    9  1.5991291e+01 8.04e-11 2.10e-01  -1.7 1.75e-05   4.1 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.5991195e+01 7.23e-10 2.10e-01  -1.7 5.26e-05   3.6 1.00e+00 1.00e+00h  1
#   11  1.5990907e+01 6.51e-09 2.10e-01  -1.7 1.58e-04   3.1 1.00e+00 1.00e+00h  1
#   12  1.5990045e+01 5.85e-08 2.10e-01  -1.7 4.73e-04   2.6 1.00e+00 1.00e+00h  1
#   13  1.5987464e+01 5.25e-07 2.10e-01  -1.7 1.42e-03   2.2 1.00e+00 1.00e+00h  1
#   14  1.5979778e+01 4.68e-06 2.09e-01  -1.7 4.23e-03   1.7 1.00e+00 1.00e+00h  1
#   15  1.5957216e+01 4.10e-05 2.06e-01  -1.7 1.26e-02   1.2 1.00e+00 1.00e+00h  1
#   16  1.5893707e+01 3.41e-04 1.99e-01  -1.7 3.64e-02   0.7 1.00e+00 1.00e+00h  1
#   17  1.5732357e+01 2.47e-03 1.80e-01  -2.5 9.89e-02   0.3 1.00e+00 1.00e+00h  1
#   18  1.5430042e+01 1.33e-02 1.36e-01  -2.5 2.26e-01  -0.2 1.00e+00 1.00e+00h  1
#   19  1.5117681e+01 5.37e-02 5.73e-02  -2.5 3.48e-01  -0.7 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  1.5080694e+01 1.18e-02 3.73e-02  -2.5 8.10e-02  -0.3 1.00e+00 1.00e+00h  1
#   21  1.5045599e+01 8.06e-03 1.92e-02  -2.5 9.35e-02  -0.7 1.00e+00 1.00e+00h  1
#   22  1.5033199e+01 2.13e-02 7.37e-03  -3.0 1.32e-01  -1.2 1.00e+00 1.00e+00h  1
#   23  1.5023084e+01 3.15e-03 2.06e-03  -3.0 7.91e-02  -1.7 1.00e+00 1.00e+00H  1
#
# Number of Iterations....: 23
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.5023083825154144e+01    1.5023083825154144e+01
# Dual infeasibility......:   2.0597409814397658e-03    2.0597409814397658e-03
# Constraint violation....:   3.1451055285506291e-03    3.1451055285506291e-03
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.0909292670104654e-04    9.0909292670104654e-04
# Overall NLP error.......:   3.1451055285506291e-03    3.1451055285506291e-03
#
#
# Number of objective function evaluations             = 27
# Number of objective gradient evaluations             = 24
# Number of equality constraint evaluations            = 27
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 24
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 23
# Total seconds in IPOPT                               = 7.570
#
# EXIT: Optimal Solution Found.
# {'solver_time': 7.674820899963379, 'termination_condition': <TerminationCondition.optimal: 'optimal'>, 'message': 'Ipopt 3.14.16\\x3a Optimal Solution Found'}
# Ipopt 3.14.16: tol=0.01
# dual_inf_tol=0.01
# compl_inf_tol=0.01
# constr_viol_tol=0.01
# acceptable_tol=1e-15
# acceptable_constr_viol_tol=1e-15
# acceptable_dual_inf_tol=1e-15
# acceptable_compl_inf_tol=1e-15
# acceptable_iter=0
# halt_on_ampl_error=yes
# print_level=5
# max_iter=1000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.16, running with linear solver MUMPS 5.7.1.
#
# Number of nonzeros in equality constraint Jacobian...:   106266
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:   121475
#
# Total number of variables............................:     2492
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:     1298
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     2388
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.4167004e+01 3.92e+00 1.29e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.5936537e+01 1.86e+00 6.07e-01  -1.0 1.46e+00  -2.0 9.77e-01 1.00e+00h  1
#    2  1.5988446e+01 4.81e-01 5.49e+00  -1.0 7.45e-01   0.2 1.00e+00 1.00e+00h  1
#    3  1.5634746e+01 3.97e-02 1.37e+01  -1.0 2.38e-01   1.6 1.00e+00 1.00e+00h  1
#    4  1.5676296e+01 1.79e-03 1.33e+01  -1.0 3.63e-02   2.0 1.00e+00 1.00e+00h  1
#    5  1.5668899e+01 1.83e-05 2.32e-01  -1.0 7.11e-03   1.5 1.00e+00 1.00e+00h  1
#    6  1.5645198e+01 9.53e-05 1.65e-01  -1.7 1.52e-02   1.0 1.00e+00 1.00e+00h  1
#    7  1.5579968e+01 7.03e-04 1.56e-01  -2.5 4.34e-02   0.6 1.00e+00 1.00e+00h  1
#    8  1.5433752e+01 4.56e-03 1.29e-01  -2.5 1.09e-01   0.1 1.00e+00 1.00e+00h  1
#    9  1.5220375e+01 1.76e-02 7.41e-02  -2.5 1.98e-01  -0.4 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.5075737e+01 2.21e-02 2.40e-02  -2.5 1.92e-01  -0.9 1.00e+00 1.00e+00h  1
#   11  1.5074815e+01 2.46e-02 2.33e-02  -3.0 2.64e+00  -1.4 1.00e+00 3.12e-02h  6
#   12  1.5039761e+01 6.26e-03 8.04e-03  -3.0 7.52e-02  -0.9 1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 12
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.5039761062155327e+01    1.5039761062155327e+01
# Dual infeasibility......:   8.0353198999269515e-03    8.0353198999269515e-03
# Constraint violation....:   6.2640922738217419e-03    6.2640922738217419e-03
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.0911961056036421e-04    9.0911961056036421e-04
# Overall NLP error.......:   8.0353198999269515e-03    8.0353198999269515e-03
#
#
# Number of objective function evaluations             = 19
# Number of objective gradient evaluations             = 13
# Number of equality constraint evaluations            = 19
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 13
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 12
# Total seconds in IPOPT                               = 4.303
#
# EXIT: Optimal Solution Found.
# {'solver_time': 4.402996778488159, 'termination_condition': <TerminationCondition.optimal: 'optimal'>, 'message': 'Ipopt 3.14.16\\x3a Optimal Solution Found'}
# Ipopt 3.14.16: tol=0.01
# dual_inf_tol=0.01
# compl_inf_tol=0.01
# constr_viol_tol=0.01
# acceptable_tol=1e-15
# acceptable_constr_viol_tol=1e-15
# acceptable_dual_inf_tol=1e-15
# acceptable_compl_inf_tol=1e-15
# acceptable_iter=0
# halt_on_ampl_error=yes
# print_level=5
# max_iter=1000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.16, running with linear solver MUMPS 5.7.1.
#
# Number of nonzeros in equality constraint Jacobian...:   106266
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:   121475
#
# Total number of variables............................:     2492
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:     1298
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     2388
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.4340488e+01 3.92e+00 1.49e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.4797687e+01 1.39e+00 2.01e-01  -1.0 1.59e+00    -  9.83e-01 1.00e+00h  1
#    2  1.5754983e+01 6.87e-01 9.31e-01  -1.0 5.64e-01   0.0 1.00e+00 1.00e+00h  1
#    3  1.5514507e+01 5.85e-02 2.76e+00  -1.7 1.34e-01   0.4 1.00e+00 1.00e+00h  1
#    4  1.5339046e+01 1.98e-03 3.72e+00  -1.7 3.40e-02   0.9 1.00e+00 1.00e+00h  1
#    5  1.5329370e+01 2.56e-05 7.19e-02  -1.7 3.25e-03   1.3 1.00e+00 1.00e+00h  1
#    6  1.5304872e+01 2.34e-04 5.93e-02  -2.5 9.40e-03   0.8 1.00e+00 1.00e+00h  1
#    7  1.5245459e+01 1.61e-03 5.05e-02  -2.5 2.40e-02   0.3 1.00e+00 1.00e+00h  1
#    8  1.5143225e+01 7.20e-03 3.33e-02  -2.5 4.76e-02  -0.2 1.00e+00 1.00e+00h  1
#    9  1.5056559e+01 1.01e-02 1.66e-02  -2.5 7.67e-02  -0.6 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.5038587e+01 3.04e-02 8.06e-03  -3.0 1.42e-01  -1.1 1.00e+00 1.00e+00h  1
#   11  1.5033330e+01 3.74e-02 3.33e-03  -3.0 9.23e-02  -1.6 1.00e+00 1.00e+00h  1
#   12  1.5024118e+01 1.46e-03 1.31e-03  -3.0 1.91e-02  -1.2 1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 12
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.5024117656493562e+01    1.5024117656493562e+01
# Dual infeasibility......:   1.3053460781062684e-03    1.3053460781062684e-03
# Constraint violation....:   1.4595035867921435e-03    1.4595035867921435e-03
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.0909090909227475e-04    9.0909090909227475e-04
# Overall NLP error.......:   1.4595035867921435e-03    1.4595035867921435e-03
#
#
# Number of objective function evaluations             = 13
# Number of objective gradient evaluations             = 13
# Number of equality constraint evaluations            = 13
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 13
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 12
# Total seconds in IPOPT                               = 3.653
#
# EXIT: Optimal Solution Found.
# {'solver_time': 3.7402749061584473, 'termination_condition': <TerminationCondition.optimal: 'optimal'>, 'message': 'Ipopt 3.14.16\\x3a Optimal Solution Found'}
# Ipopt 3.14.16: tol=0.01
# dual_inf_tol=0.01
# compl_inf_tol=0.01
# constr_viol_tol=0.01
# acceptable_tol=1e-15
# acceptable_constr_viol_tol=1e-15
# acceptable_dual_inf_tol=1e-15
# acceptable_compl_inf_tol=1e-15
# acceptable_iter=0
# halt_on_ampl_error=yes
# print_level=5
# max_iter=1000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.16, running with linear solver MUMPS 5.7.1.
#
# Number of nonzeros in equality constraint Jacobian...:   106266
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:   121475
#
# Total number of variables............................:     2492
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:     1298
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     2388
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.4207609e+01 3.92e+00 1.61e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.5293559e+01 1.55e+00 6.34e-01  -1.0 1.56e+00    -  9.80e-01 1.00e+00h  1
#    2  1.5751014e+01 7.64e-01 3.00e+02  -1.0 8.88e-01   2.0 1.00e+00 1.00e+00h  1
#    3  1.6913407e+01 3.75e-01 1.58e+04  -1.0 6.77e-01   3.3 1.00e+00 1.00e+00h  1
#    4  1.5910725e+01 1.16e-01 5.28e+04  -1.0 2.72e-01   4.7 1.00e+00 1.00e+00h  1
#    5  1.5957288e+01 9.87e-03 5.52e+04  -1.0 8.75e-02   5.1 1.00e+00 1.00e+00h  1
#    6  1.5954332e+01 8.57e-05 6.04e+03  -1.0 5.66e-03   5.5 1.00e+00 1.00e+00h  1
#    7  1.5954249e+01 4.59e-09 6.13e+00  -1.0 6.47e-05   5.0 1.00e+00 1.00e+00h  1
#    8  1.5954237e+01 1.60e-11 1.71e-01  -1.0 4.76e-06   4.6 1.00e+00 1.00e+00h  1
#    9  1.5954198e+01 1.42e-10 1.70e-01  -2.5 1.42e-05   4.1 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.5954080e+01 1.28e-09 1.70e-01  -2.5 4.25e-05   3.6 1.00e+00 1.00e+00h  1
#   11  1.5953726e+01 1.15e-08 1.70e-01  -2.5 1.27e-04   3.1 1.00e+00 1.00e+00h  1
#   12  1.5952667e+01 1.03e-07 1.70e-01  -2.5 3.82e-04   2.6 1.00e+00 1.00e+00h  1
#   13  1.5949499e+01 9.26e-07 1.69e-01  -2.5 1.15e-03   2.2 1.00e+00 1.00e+00h  1
#   14  1.5940078e+01 8.26e-06 1.69e-01  -2.5 3.42e-03   1.7 1.00e+00 1.00e+00h  1
#   15  1.5912556e+01 7.24e-05 1.67e-01  -2.5 1.02e-02   1.2 1.00e+00 1.00e+00h  1
#   16  1.5836156e+01 6.01e-04 1.63e-01  -2.5 2.97e-02   0.7 1.00e+00 1.00e+00h  1
#   17  1.5651966e+01 4.29e-03 1.49e-01  -2.5 8.19e-02   0.3 1.00e+00 1.00e+00h  1
#   18  1.5338376e+01 2.14e-02 1.11e-01  -2.5 1.89e-01  -0.2 1.00e+00 1.00e+00h  1
#   19  1.5082141e+01 7.25e-02 4.14e-02  -2.5 2.61e-01  -0.7 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  1.5039508e+01 4.89e-02 1.39e-02  -2.5 2.22e-01  -1.2 1.00e+00 1.00e+00h  1
#   21  1.5030711e+01 1.91e-03 8.72e-03  -2.5 5.51e-02  -0.7 1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 21
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.5030710663088845e+01    1.5030710663088845e+01
# Dual infeasibility......:   8.7153806301432813e-03    8.7153806301432813e-03
# Constraint violation....:   1.9144286508263608e-03    1.9144286508263608e-03
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.8284271247467742e-03    2.8284271247467742e-03
# Overall NLP error.......:   8.7153806301432813e-03    8.7153806301432813e-03
#
#
# Number of objective function evaluations             = 22
# Number of objective gradient evaluations             = 22
# Number of equality constraint evaluations            = 22
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 22
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 21
# Total seconds in IPOPT                               = 5.943
#
# EXIT: Optimal Solution Found.
# {'solver_time': 6.0308449268341064, 'termination_condition': <TerminationCondition.optimal: 'optimal'>, 'message': 'Ipopt 3.14.16\\x3a Optimal Solution Found'}
# Ipopt 3.14.16: tol=0.01
# dual_inf_tol=0.01
# compl_inf_tol=0.01
# constr_viol_tol=0.01
# acceptable_tol=1e-15
# acceptable_constr_viol_tol=1e-15
# acceptable_dual_inf_tol=1e-15
# acceptable_compl_inf_tol=1e-15
# acceptable_iter=0
# halt_on_ampl_error=yes
# print_level=5
# max_iter=1000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.16, running with linear solver MUMPS 5.7.1.
#
# Number of nonzeros in equality constraint Jacobian...:   106266
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:   121475
#
# Total number of variables............................:     2492
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:     1298
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     2388
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.4371132e+01 3.92e+00 1.64e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.5258705e+01 2.01e+00 7.28e-01  -1.0 1.55e+00    -  9.79e-01 1.00e+00h  1
#    2  1.5319513e+01 1.07e+00 8.23e-01  -1.0 8.64e-01   0.0 1.00e+00 5.00e-01h  2
#    3  1.5523519e+01 1.81e-01 2.26e+00  -1.0 4.03e-01   0.4 1.00e+00 1.00e+00h  1
#    4  1.5499280e+01 1.76e-01 1.02e+00  -1.0 3.32e-01   0.9 1.00e+00 1.00e+00h  1
#    5  1.5454621e+01 8.94e-03 2.23e+00  -1.0 1.28e-01   1.3 1.00e+00 1.00e+00h  1
#    6  1.5424624e+01 1.96e-03 1.33e-01  -1.0 4.26e-02   0.8 1.00e+00 1.00e+00h  1
#    7  1.5346334e+01 2.84e-03 1.23e-01  -2.5 5.67e-02   0.3 1.00e+00 1.00e+00h  1
#    8  1.5202888e+01 1.50e-02 9.77e-02  -2.5 1.37e-01  -0.2 1.00e+00 1.00e+00h  1
#    9  1.5056180e+01 8.23e-02 4.97e-02  -2.5 3.07e-01  -0.6 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.5044895e+01 6.30e-03 4.20e-02  -2.5 8.96e-02  -0.2 1.00e+00 1.00e+00h  1
#   11  1.5032310e+01 1.27e-03 1.58e-02  -2.5 7.92e-02  -0.7 1.00e+00 1.00e+00h  1
#   12  1.5028649e+01 5.98e-03 4.63e-03  -3.0 6.85e-02  -1.2 1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 12
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.5028649112901325e+01    1.5028649112901325e+01
# Dual infeasibility......:   4.6273680464951582e-03    4.6273680464951582e-03
# Constraint violation....:   5.9821210477233322e-03    5.9821210477233322e-03
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.1088277438369357e-04    9.1088277438369357e-04
# Overall NLP error.......:   5.9821210477233322e-03    5.9821210477233322e-03
#
#
# Number of objective function evaluations             = 15
# Number of objective gradient evaluations             = 13
# Number of equality constraint evaluations            = 15
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 13
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 12
# Total seconds in IPOPT                               = 3.170
#
# EXIT: Optimal Solution Found.
# {'solver_time': 3.2578916549682617, 'termination_condition': <TerminationCondition.optimal: 'optimal'>, 'message': 'Ipopt 3.14.16\\x3a Optimal Solution Found'}
# Ipopt 3.14.16: tol=0.01
# dual_inf_tol=0.01
# compl_inf_tol=0.01
# constr_viol_tol=0.01
# acceptable_tol=1e-15
# acceptable_constr_viol_tol=1e-15
# acceptable_dual_inf_tol=1e-15
# acceptable_compl_inf_tol=1e-15
# acceptable_iter=0
# halt_on_ampl_error=yes
# print_level=5
# max_iter=1000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.16, running with linear solver MUMPS 5.7.1.
#
# Number of nonzeros in equality constraint Jacobian...:   106266
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:   121475
#
# Total number of variables............................:     2492
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:     1298
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     2388
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.4545655e+01 3.92e+00 1.35e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.0947874e+01 5.06e-01 6.31e+00  -1.0 7.66e-01   0.0 8.90e-01 1.00e+00h  1
#    2  5.3172515e+01 3.15e-01 2.76e+01  -1.0 8.39e-01   1.3 9.91e-01 5.00e-01h  2
#    3  5.8228303e+01 1.18e-01 6.14e+03  -1.0 6.88e-01   2.7 1.00e+00 1.00e+00h  1
#    4  5.7593380e+01 8.45e-03 3.88e+03  -1.0 1.28e-01   4.0 1.00e+00 1.00e+00h  1
#    5  5.7607432e+01 7.90e-05 6.80e+02  -1.0 1.04e-02   4.4 1.00e+00 1.00e+00h  1
#    6  5.7605643e+01 7.02e-09 1.17e+00  -1.0 1.16e-04   3.9 1.00e+00 1.00e+00h  1
#    7  5.7599155e+01 4.53e-09 2.79e-01  -1.0 9.69e-05   3.5 1.00e+00 1.00e+00f  1
#    8  5.7579547e+01 4.06e-08 2.80e-01  -1.7 2.92e-04   3.0 1.00e+00 1.00e+00f  1
#    9  5.7520796e+01 3.65e-07 2.79e-01  -1.7 8.74e-04   2.5 1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  5.7345196e+01 3.26e-06 2.78e-01  -1.7 2.61e-03   2.0 1.00e+00 1.00e+00f  1
#   11  5.6824219e+01 2.88e-05 2.76e-01  -1.7 7.76e-03   1.6 1.00e+00 1.00e+00f  1
#   12  5.5312087e+01 2.49e-04 2.69e-01  -1.7 2.26e-02   1.1 1.00e+00 1.00e+00f  1
#   13  5.1193542e+01 2.06e-03 2.54e-01  -1.7 6.23e-02   0.6 1.00e+00 1.00e+00f  1
#   14  2.2198145e+01 6.03e+00 8.56e+00  -1.7 4.46e+00    -  1.00e+00 1.00e+00f  1
#   15  2.1860864e+01 1.46e+00 1.58e+02  -1.7 1.34e+00   1.0 1.00e+00 1.00e+00h  1
#   16  2.2060203e+01 4.12e-01 2.27e+02  -1.7 5.48e-01   2.4 1.00e+00 1.00e+00h  1
#   17  2.2266789e+01 1.61e-01 4.95e+02  -1.7 5.60e-01   2.8 1.00e+00 1.00e+00h  1
#   18  2.2322308e+01 4.04e-02 4.14e+03  -1.7 2.60e-01   3.2 1.00e+00 1.00e+00h  1
#   19  2.2368542e+01 1.02e-03 1.18e+03  -1.7 3.31e-02   4.5 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  2.2367830e+01 1.00e-06 3.07e+01  -1.7 9.22e-04   4.1 1.00e+00 1.00e+00h  1
#   21  2.2367235e+01 2.66e-09 3.88e-01  -1.7 1.03e-04   3.6 1.00e+00 1.00e+00h  1
#   22  2.2365452e+01 2.34e-08 3.88e-01  -1.7 3.08e-04   3.1 1.00e+00 1.00e+00f  1
#   23  2.2360106e+01 2.11e-07 3.88e-01  -1.7 9.22e-04   2.6 1.00e+00 1.00e+00f  1
#   24  2.2344116e+01 1.89e-06 3.87e-01  -1.7 2.76e-03   2.1 1.00e+00 1.00e+00f  1
#   25  2.2296552e+01 1.67e-05 3.86e-01  -1.7 8.25e-03   1.7 1.00e+00 1.00e+00f  1
#   26  2.2157411e+01 1.43e-04 3.80e-01  -1.7 2.44e-02   1.2 1.00e+00 1.00e+00f  1
#   27  2.1769229e+01 1.16e-03 3.65e-01  -1.7 7.04e-02   0.7 1.00e+00 1.00e+00f  1
#   28  2.0813039e+01 9.06e-03 3.26e-01  -1.7 1.88e-01   0.2 1.00e+00 1.00e+00f  1
#   29  1.9032825e+01 5.23e-02 2.39e-01  -1.7 4.15e-01  -0.2 1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  1.6884879e+01 2.02e-01 2.37e-01  -1.7 6.11e-01  -0.7 1.00e+00 1.00e+00h  1
#   31  1.6274781e+01 7.43e-02 2.34e-01  -1.7 2.52e-01  -0.3 1.00e+00 1.00e+00h  1
#   32  1.6009194e+01 1.74e-02 1.78e-01  -1.7 1.54e-01   0.1 1.00e+00 1.00e+00h  1
#   33  1.5636035e+01 4.93e-02 1.06e-01  -2.5 2.14e-01  -0.3 1.00e+00 1.00e+00h  1
#   34  1.5441798e+01 6.89e-01 1.01e-01  -2.5 1.17e+00  -0.8 1.00e+00 5.00e-01h  2
#   35  1.5360323e+01 5.25e-01 1.70e-01  -2.5 9.72e-01    -  1.00e+00 1.00e+00h  1
#   36  1.5141705e+01 1.53e-01 4.39e-01  -2.5 6.75e-01  -0.4 1.00e+00 1.00e+00h  1
#   37  1.5135510e+01 1.15e-01 5.70e-01  -2.5 3.60e-01   0.0 1.00e+00 1.00e+00h  1
#   38  1.5106330e+01 1.14e-02 2.99e-01  -2.5 1.75e-01   0.5 1.00e+00 1.00e+00h  1
#   39  1.5069234e+01 1.22e-02 5.71e-02  -2.5 1.31e-01  -0.0 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  1.5043997e+01 8.17e-03 2.89e-02  -2.5 8.74e-02  -0.5 1.00e+00 1.00e+00h  1
#   41  1.5032726e+01 5.86e-03 1.47e-02  -2.5 1.21e-01  -1.0 1.00e+00 1.00e+00h  1
#   42  1.5032027e+01 2.14e-02 5.85e-03  -3.0 1.38e-01  -1.4 1.00e+00 1.00e+00h  1
#   43  1.4961164e+01 2.97e-01 8.61e-03  -3.0 5.63e-01  -1.9 1.00e+00 1.00e+00H  1
#   44  1.5001677e+01 1.18e-01 7.74e-03  -3.0 1.57e-01  -2.4 1.00e+00 5.00e-01h  2
#   45  1.5028461e+01 2.00e-02 1.91e-03  -3.0 6.77e-02  -2.0 1.00e+00 1.00e+00h  1
#   46  1.5022968e+01 7.59e-04 4.54e-04  -3.0 1.66e-02  -1.6 1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 46
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.5022967824592442e+01    1.5022967824592442e+01
# Dual infeasibility......:   4.5441727648276885e-04    4.5441727648276885e-04
# Constraint violation....:   7.5862218781774793e-04    7.5862218781774793e-04
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.0909090909090909e-04    9.0909090909090909e-04
# Overall NLP error.......:   9.0909090909090909e-04    9.0909090909090909e-04
#
#
# Number of objective function evaluations             = 53
# Number of objective gradient evaluations             = 47
# Number of equality constraint evaluations            = 53
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 47
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 46
# Total seconds in IPOPT                               = 13.442
#
# EXIT: Optimal Solution Found.
# {'solver_time': 13.545673847198486, 'termination_condition': <TerminationCondition.optimal: 'optimal'>, 'message': 'Ipopt 3.14.16\\x3a Optimal Solution Found'}
# Ipopt 3.14.16: tol=0.01
# dual_inf_tol=0.01
# compl_inf_tol=0.01
# constr_viol_tol=0.01
# acceptable_tol=1e-15
# acceptable_constr_viol_tol=1e-15
# acceptable_dual_inf_tol=1e-15
# acceptable_compl_inf_tol=1e-15
# acceptable_iter=0
# halt_on_ampl_error=yes
# print_level=5
# max_iter=1000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.16, running with linear solver MUMPS 5.7.1.
#
# Number of nonzeros in equality constraint Jacobian...:   106266
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:   121475
#
# Total number of variables............................:     2492
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:     1298
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     2388
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.4269053e+01 3.92e+00 1.42e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.5125999e+01 2.08e+00 5.76e-01  -1.0 1.56e+00    -  9.81e-01 1.00e+00h  1
#    2  1.6140418e+01 1.18e+00 9.80e+00  -1.0 8.79e-01   0.0 1.00e+00 1.00e+00h  1
#    3  1.6717476e+01 7.19e-01 1.07e+02  -1.0 5.17e-01   1.3 1.00e+00 1.00e+00h  1
#    4  1.5802340e+01 8.51e-02 3.03e+02  -1.0 2.25e-01   2.7 1.00e+00 1.00e+00h  1
#    5  1.5692173e+01 2.32e-02 2.97e+02  -1.0 1.25e-01   3.1 1.00e+00 1.00e+00h  1
#    6  1.5704269e+01 5.35e-04 8.25e+01  -1.0 2.26e-02   3.5 1.00e+00 1.00e+00h  1
#    7  1.5703943e+01 1.38e-07 3.07e-01  -1.0 3.24e-04   3.0 1.00e+00 1.00e+00h  1
#    8  1.5703134e+01 1.29e-07 1.04e-01  -1.7 2.88e-04   2.6 1.00e+00 1.00e+00h  1
#    9  1.5700666e+01 1.15e-06 1.04e-01  -2.5 8.64e-04   2.1 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.5693330e+01 1.02e-05 1.03e-01  -2.5 2.58e-03   1.6 1.00e+00 1.00e+00h  1
#   11  1.5671930e+01 8.84e-05 1.02e-01  -2.5 7.65e-03   1.1 1.00e+00 1.00e+00h  1
#   12  1.5612773e+01 7.04e-04 9.80e-02  -2.5 2.21e-02   0.6 1.00e+00 1.00e+00h  1
#   13  1.5471513e+01 4.49e-03 8.69e-02  -2.5 5.94e-02   0.2 1.00e+00 1.00e+00h  1
#   14  1.5235396e+01 2.60e-02 5.52e-02  -2.5 1.27e-01  -0.3 1.00e+00 1.00e+00h  1
#   15  1.5054332e+01 6.89e-02 2.22e-02  -2.5 2.18e-01  -0.8 1.00e+00 1.00e+00h  1
#   16  1.5062494e+01 5.85e-02 2.03e-02  -2.5 1.37e+00  -1.3 1.00e+00 1.25e-01h  4
#   17  1.5034551e+01 4.23e-03 1.09e-02  -2.5 8.87e-02  -0.8 1.00e+00 1.00e+00h  1
#   18  1.5030154e+01 9.98e-03 4.33e-03  -3.0 8.65e-02  -1.3 1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 18
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.5030154089131708e+01    1.5030154089131708e+01
# Dual infeasibility......:   4.3256263820067161e-03    4.3256263820067161e-03
# Constraint violation....:   9.9769421240767375e-03    9.9769421240767375e-03
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.1158076275931128e-04    9.1158076275931128e-04
# Overall NLP error.......:   9.9769421240767375e-03    9.9769421240767375e-03
#
#
# Number of objective function evaluations             = 23
# Number of objective gradient evaluations             = 19
# Number of equality constraint evaluations            = 23
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 19
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 18
# Total seconds in IPOPT                               = 5.315
#
# EXIT: Optimal Solution Found.
# {'solver_time': 5.41352391242981, 'termination_condition': <TerminationCondition.optimal: 'optimal'>, 'message': 'Ipopt 3.14.16\\x3a Optimal Solution Found'}
# Ipopt 3.14.16: tol=0.01
# dual_inf_tol=0.01
# compl_inf_tol=0.01
# constr_viol_tol=0.01
# acceptable_tol=1e-15
# acceptable_constr_viol_tol=1e-15
# acceptable_dual_inf_tol=1e-15
# acceptable_compl_inf_tol=1e-15
# acceptable_iter=0
# halt_on_ampl_error=yes
# print_level=5
# max_iter=1000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.16, running with linear solver MUMPS 5.7.1.
#
# Number of nonzeros in equality constraint Jacobian...:   106266
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:   121475
#
# Total number of variables............................:     2492
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:     1298
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     2388
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.4296393e+01 3.92e+00 1.78e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.4993863e+01 1.59e+00 1.91e-01  -1.0 1.49e+00    -  9.82e-01 1.00e+00h  1
#    2  1.5999353e+01 4.64e-01 1.74e+00  -1.0 8.11e-01   0.0 1.00e+00 1.00e+00h  1
#    3  1.5839177e+01 9.21e-02 1.07e+02  -1.0 3.93e-01   1.3 1.00e+00 1.00e+00h  1
#    4  1.5729283e+01 7.68e-03 2.81e+02  -1.0 1.20e-01   2.7 1.00e+00 1.00e+00h  1
#    5  1.5745179e+01 8.82e-05 3.01e+01  -1.0 9.70e-03   3.1 1.00e+00 1.00e+00h  1
#    6  1.5744245e+01 1.15e-07 1.41e-01  -1.0 3.22e-04   2.6 1.00e+00 1.00e+00h  1
#    7  1.5741071e+01 8.65e-07 1.10e-01  -2.5 8.19e-04   2.1 1.00e+00 1.00e+00h  1
#    8  1.5731652e+01 7.70e-06 1.10e-01  -2.5 2.44e-03   1.7 1.00e+00 1.00e+00h  1
#    9  1.5704313e+01 6.70e-05 1.07e-01  -2.5 7.17e-03   1.2 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.5629847e+01 5.45e-04 1.01e-01  -2.5 2.03e-02   0.7 1.00e+00 1.00e+00h  1
#   11  1.5459712e+01 3.67e-03 8.33e-02  -2.5 5.14e-02   0.2 1.00e+00 1.00e+00h  1
#   12  1.5207161e+01 1.56e-02 4.47e-02  -2.5 9.72e-02  -0.3 1.00e+00 1.00e+00h  1
#   13  1.5051142e+01 2.48e-02 2.40e-02  -2.5 1.03e-01  -0.7 1.00e+00 1.00e+00h  1
#   14  1.5031669e+01 1.98e-02 5.47e-03  -3.0 8.21e-02  -1.2 1.00e+00 1.00e+00h  1
#   15  1.5023149e+01 4.65e-03 8.92e-03  -3.0 1.46e-01  -1.7 1.00e+00 1.00e+00H  1
#
# Number of Iterations....: 15
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.5023149209144199e+01    1.5023149209144199e+01
# Dual infeasibility......:   8.9215793135707343e-03    8.9215793135707343e-03
# Constraint violation....:   4.6458494582016785e-03    4.6458494582016785e-03
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.0909615607905774e-04    9.0909615607905774e-04
# Overall NLP error.......:   8.9215793135707343e-03    8.9215793135707343e-03
#
#
# Number of objective function evaluations             = 17
# Number of objective gradient evaluations             = 16
# Number of equality constraint evaluations            = 17
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 16
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 15
# Total seconds in IPOPT                               = 5.150
#
# EXIT: Optimal Solution Found.
# {'solver_time': 5.243430852890015, 'termination_condition': <TerminationCondition.optimal: 'optimal'>, 'message': 'Ipopt 3.14.16\\x3a Optimal Solution Found'}
# Ipopt 3.14.16: tol=0.01
# dual_inf_tol=0.01
# compl_inf_tol=0.01
# constr_viol_tol=0.01
# acceptable_tol=1e-15
# acceptable_constr_viol_tol=1e-15
# acceptable_dual_inf_tol=1e-15
# acceptable_compl_inf_tol=1e-15
# acceptable_iter=0
# halt_on_ampl_error=yes
# print_level=5
# max_iter=1000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.16, running with linear solver MUMPS 5.7.1.
#
# Number of nonzeros in equality constraint Jacobian...:   106266
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:   121475
#
# Total number of variables............................:     2492
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:     1298
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     2388
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.4378588e+01 3.92e+00 1.43e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.4828207e+01 1.05e+00 4.50e-01  -1.0 1.47e+00    -  9.82e-01 1.00e+00h  1
#    2  1.5422882e+01 2.95e-01 5.02e+00  -1.0 1.09e+00   0.0 1.00e+00 1.00e+00h  1
#    3  1.5367674e+01 2.76e-02 5.00e+00  -1.0 1.49e-01   1.3 1.00e+00 1.00e+00h  1
#    4  1.5390256e+01 3.28e-04 1.99e+00  -1.0 1.94e-02   1.8 1.00e+00 1.00e+00h  1
#    5  1.5381389e+01 6.81e-05 1.85e-01  -1.0 9.03e-03   1.3 1.00e+00 1.00e+00h  1
#    6  1.5351741e+01 6.39e-04 1.73e-01  -2.5 2.74e-02   0.8 1.00e+00 1.00e+00h  1
#    7  1.5278810e+01 4.86e-03 1.53e-01  -2.5 7.30e-02   0.3 1.00e+00 1.00e+00h  1
#    8  1.5150617e+01 2.67e-02 1.07e-01  -2.5 1.55e-01  -0.2 1.00e+00 1.00e+00h  1
#    9  1.5045836e+01 6.06e-02 3.91e-02  -2.5 1.84e-01  -0.6 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.5032852e+01 2.40e-02 1.15e-02  -2.5 1.48e-01  -1.1 1.00e+00 1.00e+00h  1
#   11  1.5027432e+01 7.49e-03 1.22e-03  -3.0 5.05e-02  -1.6 1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 11
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.5027432333357149e+01    1.5027432333357149e+01
# Dual infeasibility......:   1.2212834093706015e-03    1.2212834093706015e-03
# Constraint violation....:   7.4941047829837348e-03    7.4941047829837348e-03
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.1086596282676218e-04    9.1086596282676218e-04
# Overall NLP error.......:   7.4941047829837348e-03    7.4941047829837348e-03
#
#
# Number of objective function evaluations             = 12
# Number of objective gradient evaluations             = 12
# Number of equality constraint evaluations            = 12
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 12
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 11
# Total seconds in IPOPT                               = 3.207
#
# EXIT: Optimal Solution Found.
# {'solver_time': 3.2992749214172363, 'termination_condition': <TerminationCondition.optimal: 'optimal'>, 'message': 'Ipopt 3.14.16\\x3a Optimal Solution Found'}
# Ipopt 3.14.16: tol=0.01
# dual_inf_tol=0.01
# compl_inf_tol=0.01
# constr_viol_tol=0.01
# acceptable_tol=1e-15
# acceptable_constr_viol_tol=1e-15
# acceptable_dual_inf_tol=1e-15
# acceptable_compl_inf_tol=1e-15
# acceptable_iter=0
# halt_on_ampl_error=yes
# print_level=5
# max_iter=1000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.16, running with linear solver MUMPS 5.7.1.
#
# Number of nonzeros in equality constraint Jacobian...:   106266
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:   121475
#
# Total number of variables............................:     2492
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:     1298
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     2388
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.4230641e+01 3.92e+00 1.29e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.5030678e+01 1.79e+00 2.47e-01  -1.0 1.57e+00    -  9.79e-01 1.00e+00h  1
#    2  1.5306372e+01 4.25e-01 1.00e+00  -1.0 6.64e-01   0.0 1.00e+00 1.00e+00h  1
#    3  1.5402129e+01 1.94e-01 3.69e+00  -1.0 3.52e-01   0.4 1.00e+00 1.00e+00h  1
#    4  1.5319698e+01 8.17e-03 3.59e+00  -1.0 8.89e-02   1.8 1.00e+00 1.00e+00h  1
#    5  1.5310450e+01 1.86e-04 4.77e-01  -1.0 1.03e-02   1.3 1.00e+00 1.00e+00h  1
#    6  1.5291189e+01 2.40e-04 9.22e-02  -1.7 1.45e-02   0.8 1.00e+00 1.00e+00h  1
#    7  1.5242311e+01 1.58e-03 8.39e-02  -2.5 3.99e-02   0.3 1.00e+00 1.00e+00h  1
#    8  1.5153391e+01 7.97e-03 6.40e-02  -2.5 9.19e-02  -0.2 1.00e+00 1.00e+00h  1
#    9  1.5065635e+01 1.72e-02 3.16e-02  -2.5 1.41e-01  -0.6 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.5030460e+01 6.96e-03 7.23e-03  -2.5 1.01e-01  -1.1 1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 10
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.5030459969815002e+01    1.5030459969815002e+01
# Dual infeasibility......:   7.2301406587812651e-03    7.2301406587812651e-03
# Constraint violation....:   6.9557586236109747e-03    6.9557586236109747e-03
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.8284271247461957e-03    2.8284271247461957e-03
# Overall NLP error.......:   7.2301406587812651e-03    7.2301406587812651e-03
#
#
# Number of objective function evaluations             = 11
# Number of objective gradient evaluations             = 11
# Number of equality constraint evaluations            = 11
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 11
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 10
# Total seconds in IPOPT                               = 2.547
#
# EXIT: Optimal Solution Found.
# {'solver_time': 2.635686159133911, 'termination_condition': <TerminationCondition.optimal: 'optimal'>, 'message': 'Ipopt 3.14.16\\x3a Optimal Solution Found'}

# %%
print(f"Average time elpased: {solver_time/10:.3f}")
print(f"Average mae_train: {mae_train/10:.3f}")
print(f"Average mae_test: {mae_test/10:.3f}")
# Out:
# Average time elpased: 5.524
# Average mae_train: 0.021
# Average mae_test: 0.030

# %%
y0 = np.array([0.0, 1.0])
y_pred = ode_model.neural_ode(y0, t_ho_cheb)
y1 = y_test_ho_cheb[-1]
y_pred_test = ode_model.neural_ode(y0, t_test_ho_cheb)

#print(f"Mean Absolute Error - Direct: {np.mean(np.abs(y_ho_cheb - u_model))}")
#print(f"Mean Absolute Error - ODE solver: {np.mean(np.abs(y_ho_cheb - y_pred))}")

#y0_test = y_test_scaled[0]
#y_pred_test = ode_model.neural_ode(y0_test, ts_test, (Xs_test, ts_test))

plt.figure(figsize=(20, 10))
"""plt.plot(ts, y_ho_cheb, label='True Data', alpha = 1)

plt.plot(ts, u_model[0], label='Model Prediction - Direct', alpha = 0.75)
#plt.scatter(ts, y_pred[:,0], label='Model Prediction (Train) - Odeint')
plt.plot(ts, u_model[1], label='Model Prediction - Direct', alpha = 0.75)"""
#plt.scatter(ts, y_pred[:,1], label='Model Prediction (Train) - Odeint')

plt.plot(t_test_ho_cheb, y_test_ho_cheb[:,0], label='Model Prediction (Test) - True Data', alpha = 0.6)
plt.plot(t_test_ho_cheb, y_test_ho_cheb[:,1], alpha = 0.6)
plt.scatter(t_test_ho_cheb, y_pred_test[:,0], label='Model Prediction (Test) - Odeint', alpha = 0.6)
plt.scatter(t_test_ho_cheb, y_pred_test[:,1], alpha = 0.6)
plt.legend(loc ="lower right")
plt.grid(True)
plt.show()

# %%
np.array(t_ho_cheb).shape
# Out:
# (200,)

# %%
y0 = np.array([0.0, 1.0])
solver_time = 0
mae_train, mae_test = 0, 0
for i in range(10):
    start_timer_build = time.time()
    ode_model = NeuralODEPyomo_cont(np.array(y_noisy_ho_cheb), # y
                            np.array(t_ho_cheb), # t
                            np.array(None),
                            
                            layer_widths, act_func = "tanh", 
                            y_init = np.array(estimated_solution_ho_cheb), 
                            penalty_lambda_reg = 0.1, 
                            time_invariant = True,
                            # extra_input 
                            w_init_method = 'xavier', 
                            params = params,
                            deriv_method = "pyomo",
                            is_continuous = True
                            )

    ode_model.build_model()
    end_timer_build = time.time()
    result = ode_model.solve_model()
    u_model = ode_model.extract_solution()
    solver_time += result['solver_time']
    
    y_pred = ode_model.neural_ode(y0, t_ho)
    y1 = y_test_ho[-1]
    y_pred_test = ode_model.neural_ode(y0, t_test_ho)
    
    mae_train += np.mean(np.abs(y_ho - y_pred))
    mae_test += np.mean(np.abs(y_test_ho - y_pred_test))

# %%
import nn_pyomo_continious
importlib.reload(nn_pyomo_continious)
NeuralODEPyomo_cont = nn_pyomo_continious.NeuralODEPyomo

layer_widths = [2, 20, 2]

# solver.options['print_level'] = 5
tol = 1e-2
params = {"tol":1e-2, 
          "dual_inf_tol": tol, 
          "compl_inf_tol": tol,
          "constr_viol_tol": tol, 
          
          # repeat the same for the acceptable tolerances
          "acceptable_tol": 1e-15,
          "acceptable_constr_viol_tol": 1e-15,
          "acceptable_dual_inf_tol": 1e-15,
          "acceptable_compl_inf_tol": 1e-15,
          "acceptable_iter": 0, 
          
          "halt_on_ampl_error" : 'yes',
          "print_level": 5, 
          #"hessian_approximation": 'limited-memory', 
          #"mu_strategy": 'adaptive', 
          #"check_derivatives_for_naninf": 'yes',
          "max_iter": 1000}

y0 = np.array([0.0, 1.0])
solver_time = 0
mae_train, mae_test = 0, 0
for i in range(10):
    ode_model = NeuralODEPyomo_cont(np.array(y_noisy_ho_cheb), # y
                            np.array(t_ho_cheb), # t
                            np.array(D_ho_cheb),
                            
                            layer_widths, act_func = "tanh", 
                            y_init = np.array(estimated_solution_ho_cheb), 
                            penalty_lambda_reg = 0.1, 
                            time_invariant = True,
                            w_init_method = 'xavier', 
                            params = params,
                            deriv_method = "collocation",
                            is_continuous = True
                            )

    ode_model.build_model()
    result = ode_model.solve_model()
    u_model = ode_model.extract_solution()
    solver_time += result['solver_time']
    
    y_pred = ode_model.neural_ode(y0, t_ho)
    y1 = y_test_ho[-1]
    y_pred_test = ode_model.neural_ode(y0, t_test_ho)
    
    mae_train += np.mean(np.abs(y_ho - y_pred))
    mae_test += np.mean(np.abs(y_test_ho - y_pred_test))
# Out:
# Ipopt 3.14.16: tol=0.01
# dual_inf_tol=0.01
# compl_inf_tol=0.01
# constr_viol_tol=0.01
# acceptable_tol=1e-15
# acceptable_constr_viol_tol=1e-15
# acceptable_dual_inf_tol=1e-15
# acceptable_compl_inf_tol=1e-15
# acceptable_iter=0
# halt_on_ampl_error=yes
# print_level=5
# max_iter=1000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.16, running with linear solver MUMPS 5.7.1.
#
# Number of nonzeros in equality constraint Jacobian...:   112236
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:    40681
#
# Total number of variables............................:      502
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      502
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      398
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.4374993e+01 1.92e+00 1.37e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.4888484e+01 9.74e-01 2.66e-01  -1.0 7.53e-01    -  9.84e-01 1.00e+00h  1
#    2  1.6236681e+01 9.37e-01 6.38e+00  -1.0 1.19e+00   0.0 1.00e+00 1.00e+00h  1
#    3  1.5852387e+01 5.70e-02 3.73e+00  -1.0 2.27e-01   1.3 1.00e+00 1.00e+00h  1
#    4  1.5547980e+01 2.03e-02 1.57e+00  -1.0 1.30e-01   0.9 1.00e+00 1.00e+00h  1
#    5  1.5300226e+01 1.10e-02 3.97e-01  -1.0 8.20e-02   0.4 1.00e+00 1.00e+00h  1
#    6  1.5107616e+01 4.58e-02 1.18e-01  -1.7 1.73e-01  -0.1 1.00e+00 1.00e+00h  1
#    7  1.5026360e+01 7.71e-02 3.85e-02  -2.5 1.52e-01  -0.6 1.00e+00 1.00e+00h  1
#    8  1.5030769e+01 9.68e-03 7.60e-03  -2.5 8.70e-02  -1.1 1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 8
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.5030768632551920e+01    1.5030768632551920e+01
# Dual infeasibility......:   7.5982322489474199e-03    7.5982322489474199e-03
# Constraint violation....:   9.6765559665221469e-03    9.6765559665221469e-03
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.8284436194919295e-03    2.8284436194919295e-03
# Overall NLP error.......:   9.6765559665221469e-03    9.6765559665221469e-03
#
#
# Number of objective function evaluations             = 9
# Number of objective gradient evaluations             = 9
# Number of equality constraint evaluations            = 9
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 9
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 8
# Total seconds in IPOPT                               = 0.819
#
# EXIT: Optimal Solution Found.
# {'solver_time': 0.9226889610290527, 'termination_condition': <TerminationCondition.optimal: 'optimal'>, 'message': 'Ipopt 3.14.16\\x3a Optimal Solution Found'}
# Ipopt 3.14.16: tol=0.01
# dual_inf_tol=0.01
# compl_inf_tol=0.01
# constr_viol_tol=0.01
# acceptable_tol=1e-15
# acceptable_constr_viol_tol=1e-15
# acceptable_dual_inf_tol=1e-15
# acceptable_compl_inf_tol=1e-15
# acceptable_iter=0
# halt_on_ampl_error=yes
# print_level=5
# max_iter=1000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.16, running with linear solver MUMPS 5.7.1.
#
# Number of nonzeros in equality constraint Jacobian...:   112236
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:    40681
#
# Total number of variables............................:      502
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      502
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      398
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.4462152e+01 1.71e+00 1.72e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.4688033e+01 1.23e+00 1.45e-01  -1.0 1.03e+00    -  9.81e-01 1.00e+00h  1
#    2  1.6184370e+01 8.47e-01 1.67e+00  -1.0 7.79e-01   0.0 1.00e+00 1.00e+00h  1
#    3  1.5473656e+01 7.63e-02 1.01e+00  -1.0 2.29e-01   0.4 1.00e+00 1.00e+00h  1
#    4  1.5306270e+01 2.06e-03 3.32e-01  -1.0 3.71e-02   0.9 1.00e+00 1.00e+00h  1
#    5  1.5158702e+01 2.24e-03 1.22e-01  -1.7 3.05e-02   0.4 1.00e+00 1.00e+00h  1
#    6  1.5073355e+01 9.59e-03 5.39e-02  -2.5 7.09e-02  -0.1 1.00e+00 1.00e+00h  1
#    7  1.5044655e+01 1.33e-02 2.99e-02  -2.5 1.19e-01  -0.6 1.00e+00 1.00e+00h  1
#    8  1.5042614e+01 3.57e-02 1.52e-02  -2.5 1.51e-01  -1.1 1.00e+00 1.00e+00h  1
#    9  1.5041090e+01 4.15e-02 1.43e-02  -2.5 4.97e-01  -1.5 1.00e+00 1.25e-01h  4
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.5027460e+01 9.04e-03 7.47e-03  -2.5 9.41e-02  -1.1 1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 10
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.5027460177771342e+01    1.5027460177771342e+01
# Dual infeasibility......:   7.4714591449432577e-03    7.4714591449432577e-03
# Constraint violation....:   9.0404119555577839e-03    9.0404119555577839e-03
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.8284344346229109e-03    2.8284344346229109e-03
# Overall NLP error.......:   9.0404119555577839e-03    9.0404119555577839e-03
#
#
# Number of objective function evaluations             = 16
# Number of objective gradient evaluations             = 11
# Number of equality constraint evaluations            = 16
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 11
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 10
# Total seconds in IPOPT                               = 1.125
#
# EXIT: Optimal Solution Found.
# {'solver_time': 1.21632981300354, 'termination_condition': <TerminationCondition.optimal: 'optimal'>, 'message': 'Ipopt 3.14.16\\x3a Optimal Solution Found'}
# Ipopt 3.14.16: tol=0.01
# dual_inf_tol=0.01
# compl_inf_tol=0.01
# constr_viol_tol=0.01
# acceptable_tol=1e-15
# acceptable_constr_viol_tol=1e-15
# acceptable_dual_inf_tol=1e-15
# acceptable_compl_inf_tol=1e-15
# acceptable_iter=0
# halt_on_ampl_error=yes
# print_level=5
# max_iter=1000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.16, running with linear solver MUMPS 5.7.1.
#
# Number of nonzeros in equality constraint Jacobian...:   112236
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:    40681
#
# Total number of variables............................:      502
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      502
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      398
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.4336631e+01 2.05e+00 1.42e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.4683695e+01 1.50e+00 1.81e-01  -1.0 8.17e-01    -  9.83e-01 1.00e+00h  1
#    2  1.6458953e+01 3.98e-01 2.65e+00  -1.0 9.75e-01   0.0 1.00e+00 1.00e+00h  1
#    3  1.6354007e+01 6.17e-02 2.55e+01  -1.0 1.38e-01   1.3 1.00e+00 1.00e+00h  1
#    4  1.6145485e+01 1.26e-03 1.11e+01  -1.0 2.78e-02   1.8 1.00e+00 1.00e+00h  1
#    5  1.5998977e+01 1.16e-04 3.14e-01  -1.0 1.14e-02   1.3 1.00e+00 1.00e+00h  1
#    6  1.5711617e+01 1.14e-03 1.75e-01  -1.7 2.81e-02   0.8 1.00e+00 1.00e+00f  1
#    7  1.5369133e+01 6.35e-03 1.39e-01  -2.5 6.60e-02   0.3 1.00e+00 1.00e+00h  1
#    8  1.5137587e+01 2.90e-02 1.02e-01  -2.5 1.46e-01  -0.2 1.00e+00 1.00e+00h  1
#    9  1.5020384e+01 7.77e-02 3.78e-02  -2.5 1.85e-01  -0.6 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.5022546e+01 3.43e-02 4.59e-03  -2.5 1.24e-01  -1.1 1.00e+00 1.00e+00h  1
#   11  1.5027902e+01 1.77e-02 2.41e-03  -2.5 7.19e-02  -1.6 1.00e+00 1.00e+00h  1
#   12  1.5023811e+01 7.49e-04 1.23e-03  -3.0 1.73e-02  -1.2 1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 12
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.5023811019183713e+01    1.5023811019183713e+01
# Dual infeasibility......:   1.2282670523991498e-03    1.2282670523991498e-03
# Constraint violation....:   7.4884812375685533e-04    7.4884812375685533e-04
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.0942172581052029e-04    9.0942172581052029e-04
# Overall NLP error.......:   1.2282670523991498e-03    1.2282670523991498e-03
#
#
# Number of objective function evaluations             = 13
# Number of objective gradient evaluations             = 13
# Number of equality constraint evaluations            = 13
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 13
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 12
# Total seconds in IPOPT                               = 1.264
#
# EXIT: Optimal Solution Found.
# {'solver_time': 1.3858091831207275, 'termination_condition': <TerminationCondition.optimal: 'optimal'>, 'message': 'Ipopt 3.14.16\\x3a Optimal Solution Found'}
# Ipopt 3.14.16: tol=0.01
# dual_inf_tol=0.01
# compl_inf_tol=0.01
# constr_viol_tol=0.01
# acceptable_tol=1e-15
# acceptable_constr_viol_tol=1e-15
# acceptable_dual_inf_tol=1e-15
# acceptable_compl_inf_tol=1e-15
# acceptable_iter=0
# halt_on_ampl_error=yes
# print_level=5
# max_iter=1000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.16, running with linear solver MUMPS 5.7.1.
#
# Number of nonzeros in equality constraint Jacobian...:   112236
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:    40681
#
# Total number of variables............................:      502
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      502
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      398
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.4287742e+01 1.99e+00 1.26e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.4883224e+01 1.71e+00 2.93e-01  -1.0 7.12e-01    -  9.84e-01 1.00e+00h  1
#    2  1.5826827e+01 6.82e-01 3.96e+00  -1.0 5.69e-01   0.0 1.00e+00 1.00e+00h  1
#    3  1.5436600e+01 5.83e-02 2.31e+00  -1.0 1.58e-01   1.3 1.00e+00 1.00e+00h  1
#    4  1.5206270e+01 1.17e-02 5.92e-01  -1.0 9.89e-02   0.9 1.00e+00 1.00e+00h  1
#    5  1.5091448e+01 1.84e-03 1.44e-01  -1.7 2.84e-02   0.4 1.00e+00 1.00e+00h  1
#    6  1.5040671e+01 2.69e-03 2.26e-02  -2.5 3.04e-02  -0.1 1.00e+00 1.00e+00h  1
#    7  1.5029394e+01 4.92e-03 1.63e-02  -3.0 6.25e-02  -0.6 1.00e+00 1.00e+00h  1
#    8  1.5027019e+01 5.55e-03 7.05e-03  -3.0 7.76e-02  -1.1 1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 8
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.5027018804859058e+01    1.5027018804859058e+01
# Dual infeasibility......:   7.0529304679067192e-03    7.0529304679067192e-03
# Constraint violation....:   5.5485026252672150e-03    5.5485026252672150e-03
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.0909204922662030e-04    9.0909204922662030e-04
# Overall NLP error.......:   7.0529304679067192e-03    7.0529304679067192e-03
#
#
# Number of objective function evaluations             = 9
# Number of objective gradient evaluations             = 9
# Number of equality constraint evaluations            = 9
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 9
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 8
# Total seconds in IPOPT                               = 0.723
#
# EXIT: Optimal Solution Found.
# {'solver_time': 0.8113448619842529, 'termination_condition': <TerminationCondition.optimal: 'optimal'>, 'message': 'Ipopt 3.14.16\\x3a Optimal Solution Found'}
# Ipopt 3.14.16: tol=0.01
# dual_inf_tol=0.01
# compl_inf_tol=0.01
# constr_viol_tol=0.01
# acceptable_tol=1e-15
# acceptable_constr_viol_tol=1e-15
# acceptable_dual_inf_tol=1e-15
# acceptable_compl_inf_tol=1e-15
# acceptable_iter=0
# halt_on_ampl_error=yes
# print_level=5
# max_iter=1000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.16, running with linear solver MUMPS 5.7.1.
#
# Number of nonzeros in equality constraint Jacobian...:   112236
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:    40681
#
# Total number of variables............................:      502
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      502
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      398
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.4456019e+01 1.80e+00 1.60e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.4885190e+01 1.46e+00 2.99e-01  -1.0 7.67e-01    -  9.83e-01 1.00e+00h  1
#    2  1.6151094e+01 1.23e+00 2.10e+00  -1.0 7.93e-01   0.0 1.00e+00 1.00e+00h  1
#    3  1.5755230e+01 1.78e-01 5.25e+00  -1.0 2.24e-01   1.3 1.00e+00 1.00e+00h  1
#    4  1.5458319e+01 6.41e-03 2.89e+00  -1.0 5.40e-02   1.8 1.00e+00 1.00e+00h  1
#    5  1.5401131e+01 9.24e-05 9.58e-01  -1.0 1.08e-02   1.3 1.00e+00 1.00e+00h  1
#    6  1.5269032e+01 4.68e-04 7.94e-02  -1.7 1.27e-02   0.8 1.00e+00 1.00e+00f  1
#    7  1.5122349e+01 1.93e-03 5.04e-02  -2.5 2.43e-02   0.3 1.00e+00 1.00e+00h  1
#    8  1.5050083e+01 6.06e-03 3.38e-02  -2.5 4.73e-02  -0.2 1.00e+00 1.00e+00h  1
#    9  1.5029567e+01 6.57e-03 1.65e-02  -2.5 6.90e-02  -0.6 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.5028075e+01 7.17e-03 7.03e-03  -3.0 9.21e-02  -1.1 1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 10
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.5028074654703458e+01    1.5028074654703458e+01
# Dual infeasibility......:   7.0323088188883791e-03    7.0323088188883791e-03
# Constraint violation....:   7.1658962706870888e-03    7.1658962706870888e-03
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.1085539141138932e-04    9.1085539141138932e-04
# Overall NLP error.......:   7.1658962706870888e-03    7.1658962706870888e-03
#
#
# Number of objective function evaluations             = 11
# Number of objective gradient evaluations             = 11
# Number of equality constraint evaluations            = 11
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 11
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 10
# Total seconds in IPOPT                               = 1.260
#
# EXIT: Optimal Solution Found.
# {'solver_time': 1.3538460731506348, 'termination_condition': <TerminationCondition.optimal: 'optimal'>, 'message': 'Ipopt 3.14.16\\x3a Optimal Solution Found'}
# Ipopt 3.14.16: tol=0.01
# dual_inf_tol=0.01
# compl_inf_tol=0.01
# constr_viol_tol=0.01
# acceptable_tol=1e-15
# acceptable_constr_viol_tol=1e-15
# acceptable_dual_inf_tol=1e-15
# acceptable_compl_inf_tol=1e-15
# acceptable_iter=0
# halt_on_ampl_error=yes
# print_level=5
# max_iter=1000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.16, running with linear solver MUMPS 5.7.1.
#
# Number of nonzeros in equality constraint Jacobian...:   112236
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:    40681
#
# Total number of variables............................:      502
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      502
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      398
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.4488073e+01 1.78e+00 2.20e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.4749499e+01 1.37e+00 1.84e-01  -1.0 9.39e-01    -  9.82e-01 1.00e+00h  1
#    2  1.6200546e+01 1.07e+00 4.21e+00  -1.0 7.24e-01   0.0 1.00e+00 1.00e+00h  1
#    3  1.5768354e+01 9.81e-02 3.24e+00  -1.0 1.37e-01   1.3 1.00e+00 1.00e+00h  1
#    4  1.5399913e+01 1.28e-01 1.90e+00  -1.0 3.85e-01   0.9 1.00e+00 1.00e+00h  1
#    5  1.5204876e+01 2.90e-01 3.23e-01  -1.0 4.20e-01   0.4 1.00e+00 1.00e+00h  1
#    6  1.5063067e+01 8.89e-02 7.47e-02  -1.7 1.82e-01  -0.1 1.00e+00 1.00e+00h  1
#    7  1.5028804e+01 3.43e-02 2.06e-02  -2.5 1.19e-01  -0.6 1.00e+00 1.00e+00h  1
#    8  1.5025590e+01 8.96e-03 6.48e-03  -2.5 6.67e-02  -1.1 1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 8
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.5025590149349823e+01    1.5025590149349823e+01
# Dual infeasibility......:   6.4766512736954699e-03    6.4766512736954699e-03
# Constraint violation....:   8.9591035254899497e-03    8.9591035254899497e-03
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.8284624053539265e-03    2.8284624053539265e-03
# Overall NLP error.......:   8.9591035254899497e-03    8.9591035254899497e-03
#
#
# Number of objective function evaluations             = 9
# Number of objective gradient evaluations             = 9
# Number of equality constraint evaluations            = 9
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 9
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 8
# Total seconds in IPOPT                               = 1.009
#
# EXIT: Optimal Solution Found.
# {'solver_time': 1.1011567115783691, 'termination_condition': <TerminationCondition.optimal: 'optimal'>, 'message': 'Ipopt 3.14.16\\x3a Optimal Solution Found'}
# Ipopt 3.14.16: tol=0.01
# dual_inf_tol=0.01
# compl_inf_tol=0.01
# constr_viol_tol=0.01
# acceptable_tol=1e-15
# acceptable_constr_viol_tol=1e-15
# acceptable_dual_inf_tol=1e-15
# acceptable_compl_inf_tol=1e-15
# acceptable_iter=0
# halt_on_ampl_error=yes
# print_level=5
# max_iter=1000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.16, running with linear solver MUMPS 5.7.1.
#
# Number of nonzeros in equality constraint Jacobian...:   112236
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:    40681
#
# Total number of variables............................:      502
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      502
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      398
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.4397437e+01 1.84e+00 1.57e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.4745780e+01 1.10e+00 2.00e-01  -1.0 6.31e-01    -  9.85e-01 1.00e+00h  1
#    2  1.5793432e+01 3.62e-01 1.56e+00  -1.0 4.46e-01   0.0 1.00e+00 1.00e+00h  1
#    3  1.5284073e+01 2.55e-02 5.64e-01  -1.0 8.25e-02   0.4 1.00e+00 1.00e+00h  1
#    4  1.5043179e+01 5.97e-02 2.14e-01  -1.7 9.65e-02  -0.1 1.00e+00 1.00e+00h  1
#    5  1.5027665e+01 8.51e-02 4.66e-02  -1.7 1.53e-01  -0.5 1.00e+00 1.00e+00h  1
#    6  1.5022699e+01 2.28e-02 9.34e-03  -2.5 9.52e-02  -1.0 1.00e+00 1.00e+00h  1
#    7  1.5029153e+01 1.45e-02 2.52e-03  -3.0 9.53e-02  -1.5 1.00e+00 1.00e+00h  1
#    8  1.5027831e+01 1.53e-02 2.18e-03  -3.0 8.23e-02  -2.0 1.00e+00 1.00e+00h  1
#    9  1.5023075e+01 9.69e-04 4.93e-04  -3.0 1.64e-02  -1.5 1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 9
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.5023074503245722e+01    1.5023074503245722e+01
# Dual infeasibility......:   4.9330404905235177e-04    4.9330404905235177e-04
# Constraint violation....:   9.6861737033667947e-04    9.6861737033667947e-04
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.0909090909090790e-04    9.0909090909090790e-04
# Overall NLP error.......:   9.6861737033667947e-04    9.6861737033667947e-04
#
#
# Number of objective function evaluations             = 10
# Number of objective gradient evaluations             = 10
# Number of equality constraint evaluations            = 10
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 10
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 9
# Total seconds in IPOPT                               = 1.474
#
# EXIT: Optimal Solution Found.
# {'solver_time': 1.5743050575256348, 'termination_condition': <TerminationCondition.optimal: 'optimal'>, 'message': 'Ipopt 3.14.16\\x3a Optimal Solution Found'}
# Ipopt 3.14.16: tol=0.01
# dual_inf_tol=0.01
# compl_inf_tol=0.01
# constr_viol_tol=0.01
# acceptable_tol=1e-15
# acceptable_constr_viol_tol=1e-15
# acceptable_dual_inf_tol=1e-15
# acceptable_compl_inf_tol=1e-15
# acceptable_iter=0
# halt_on_ampl_error=yes
# print_level=5
# max_iter=1000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.16, running with linear solver MUMPS 5.7.1.
#
# Number of nonzeros in equality constraint Jacobian...:   112236
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:    40681
#
# Total number of variables............................:      502
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      502
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      398
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.4469499e+01 1.37e+00 1.48e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.4859860e+01 1.04e+00 2.14e-01  -1.0 6.65e-01    -  9.84e-01 1.00e+00h  1
#    2  1.6174279e+01 2.00e-01 1.61e+00  -1.0 5.01e-01   0.0 1.00e+00 1.00e+00h  1
#    3  1.5605897e+01 1.02e-02 1.84e+00  -1.0 1.03e-01   1.3 1.00e+00 1.00e+00h  1
#    4  1.5402200e+01 2.66e-04 1.09e+00  -1.0 1.88e-02   0.9 1.00e+00 1.00e+00h  1
#    5  1.5152471e+01 1.47e-02 9.99e-02  -1.0 9.40e-02   0.4 1.00e+00 1.00e+00f  1
#    6  1.5050288e+01 2.53e-03 3.74e-02  -2.5 5.14e-02  -0.1 1.00e+00 1.00e+00h  1
#    7  1.5034819e+01 2.32e-03 2.01e-02  -2.5 7.33e-02  -0.6 1.00e+00 1.00e+00h  1
#    8  1.5033488e+01 1.49e-02 9.10e-03  -3.0 1.02e-01  -1.1 1.00e+00 1.00e+00h  1
#    9  1.5026361e+01 8.91e-04 7.51e-03  -3.0 3.17e-02  -0.6 1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 9
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.5026360869100969e+01    1.5026360869100969e+01
# Dual infeasibility......:   7.5105697025953464e-03    7.5105697025953464e-03
# Constraint violation....:   8.9107397605721339e-04    8.9107397605721339e-04
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.0909141314026256e-04    9.0909141314026256e-04
# Overall NLP error.......:   7.5105697025953464e-03    7.5105697025953464e-03
#
#
# Number of objective function evaluations             = 10
# Number of objective gradient evaluations             = 10
# Number of equality constraint evaluations            = 10
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 10
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 9
# Total seconds in IPOPT                               = 1.031
#
# EXIT: Optimal Solution Found.
# {'solver_time': 1.1187880039215088, 'termination_condition': <TerminationCondition.optimal: 'optimal'>, 'message': 'Ipopt 3.14.16\\x3a Optimal Solution Found'}
# Ipopt 3.14.16: tol=0.01
# dual_inf_tol=0.01
# compl_inf_tol=0.01
# constr_viol_tol=0.01
# acceptable_tol=1e-15
# acceptable_constr_viol_tol=1e-15
# acceptable_dual_inf_tol=1e-15
# acceptable_compl_inf_tol=1e-15
# acceptable_iter=0
# halt_on_ampl_error=yes
# print_level=5
# max_iter=1000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.16, running with linear solver MUMPS 5.7.1.
#
# Number of nonzeros in equality constraint Jacobian...:   112236
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:    40681
#
# Total number of variables............................:      502
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      502
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      398
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.4323058e+01 1.32e+00 1.36e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.5089140e+01 6.30e-01 3.32e-01  -1.0 5.71e-01    -  9.85e-01 1.00e+00h  1
#    2  1.5856234e+01 9.14e-02 1.10e+00  -1.0 2.10e-01   0.0 1.00e+00 1.00e+00h  1
#    3  1.5155911e+01 3.83e-02 1.63e+00  -1.0 1.13e-01   0.4 1.00e+00 1.00e+00h  1
#    4  1.5090754e+01 3.52e-04 6.88e-02  -1.0 9.63e-03   0.9 1.00e+00 1.00e+00h  1
#    5  1.5055862e+01 3.31e-04 2.84e-02  -2.5 1.20e-02   0.4 1.00e+00 1.00e+00h  1
#    6  1.5038067e+01 1.11e-03 2.03e-02  -2.5 2.57e-02  -0.1 1.00e+00 1.00e+00h  1
#    7  1.5031958e+01 2.52e-03 1.13e-02  -3.0 4.29e-02  -0.6 1.00e+00 1.00e+00h  1
#    8  1.5030587e+01 9.21e-03 6.05e-03  -3.0 7.37e-02  -1.1 1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 8
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.5030586836131953e+01    1.5030586836131953e+01
# Dual infeasibility......:   6.0502758845522361e-03    6.0502758845522361e-03
# Constraint violation....:   9.2111701342792764e-03    9.2111701342792764e-03
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.0909130218107541e-04    9.0909130218107541e-04
# Overall NLP error.......:   9.2111701342792764e-03    9.2111701342792764e-03
#
#
# Number of objective function evaluations             = 9
# Number of objective gradient evaluations             = 9
# Number of equality constraint evaluations            = 9
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 9
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 8
# Total seconds in IPOPT                               = 0.663
#
# EXIT: Optimal Solution Found.
# {'solver_time': 0.7551898956298828, 'termination_condition': <TerminationCondition.optimal: 'optimal'>, 'message': 'Ipopt 3.14.16\\x3a Optimal Solution Found'}
# Ipopt 3.14.16: tol=0.01
# dual_inf_tol=0.01
# compl_inf_tol=0.01
# constr_viol_tol=0.01
# acceptable_tol=1e-15
# acceptable_constr_viol_tol=1e-15
# acceptable_dual_inf_tol=1e-15
# acceptable_compl_inf_tol=1e-15
# acceptable_iter=0
# halt_on_ampl_error=yes
# print_level=5
# max_iter=1000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.16, running with linear solver MUMPS 5.7.1.
#
# Number of nonzeros in equality constraint Jacobian...:   112236
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:    40681
#
# Total number of variables............................:      502
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      502
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      398
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.4439741e+01 2.14e+00 1.57e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.4787539e+01 1.52e+00 2.26e-01  -1.0 8.30e-01    -  9.83e-01 1.00e+00h  1
#    2  1.6061992e+01 7.11e-01 1.56e+00  -1.0 8.35e-01   0.0 1.00e+00 1.00e+00h  1
#    3  1.5427288e+01 4.58e-02 6.64e-01  -1.0 1.44e-01   0.4 1.00e+00 1.00e+00h  1
#    4  1.5253109e+01 1.87e-03 3.25e-01  -1.7 4.47e-02   0.9 1.00e+00 1.00e+00h  1
#    5  1.5135019e+01 2.46e-03 1.09e-01  -1.7 3.04e-02   0.4 1.00e+00 1.00e+00h  1
#    6  1.5055815e+01 1.19e-02 4.72e-02  -2.5 6.38e-02  -0.1 1.00e+00 1.00e+00h  1
#    7  1.5028184e+01 1.47e-02 1.90e-02  -2.5 7.41e-02  -0.6 1.00e+00 1.00e+00h  1
#    8  1.5026656e+01 4.92e-03 5.26e-03  -3.0 6.17e-02  -1.1 1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 8
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.5026656332860117e+01    1.5026656332860117e+01
# Dual infeasibility......:   5.2566002210633666e-03    5.2566002210633666e-03
# Constraint violation....:   4.9155573637362417e-03    4.9155573637362417e-03
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.1027581347551275e-04    9.1027581347551275e-04
# Overall NLP error.......:   5.2566002210633666e-03    5.2566002210633666e-03
#
#
# Number of objective function evaluations             = 9
# Number of objective gradient evaluations             = 9
# Number of equality constraint evaluations            = 9
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 9
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 8
# Total seconds in IPOPT                               = 0.728
#
# EXIT: Optimal Solution Found.
# {'solver_time': 0.8155519962310791, 'termination_condition': <TerminationCondition.optimal: 'optimal'>, 'message': 'Ipopt 3.14.16\\x3a Optimal Solution Found'}

# %%
print(f"Average time elpased: {solver_time/10:.3f}")
print(f"Average mae_train: {mae_train/10:.3f}")
print(f"Average mae_test: {mae_test/10:.3f}")
# Out:
# Average time elpased: 1.106
# Average mae_train: 0.021
# Average mae_test: 0.029

# %% [markdown]
# ---
# ---

# %%
#---------------------------------------------DATA PARAMS---------------------------------------------#
N = 200
noise_level = 0.1
ode_type, params = "van_der_pol", {"mu": 1, "omega": 1}
start_time, end_time = 0, 15
spacing_type = "chebyshev" # "equally_spaced" or "chebyshev"
initial_state = jnp.array([0.0, 1.0])

#--------------------------------------------GENERATE DATA--------------------------------------------#
t_vdp, y_vdp, y_noisy_vdp, true_derivatives_vdp = generate_ode_data(N, noise_level, ode_type, params, start_time, end_time, spacing_type, initial_state)

# numpy array is required for pyomo
y_noisy_vdp = np.array(jnp.squeeze(y_noisy_vdp))
t_vdp = np.array(jnp.squeeze(t_vdp))

#-----------------------------------------COLLOCATION MATRIX PREPARATION-------------------------------------------#
weights = compute_weights(t_vdp)
D_vdp = np.array(lagrange_derivative(t_vdp, weights))

#---------------------------------------------------TEST DATA--------------------------------------------#
t_test_vdp, y_test_vdp, _, _ = generate_ode_data(N*2, noise_level, ode_type, params, start_time, end_time*2, "uniform", initial_state)

#--------------------------------------------NON-PARAMETRIC COLLOCATION--------------------------------------------#
estimated_derivative_vdp, estimated_solution_vdp = collocate_data(y_noisy_vdp, t_vdp, 'EpanechnikovKernel', bandwidth=0.5)
# Out:
# /Users/mariiashapo/Library/CloudStorage/OneDrive-Personal/project_2324/NODE/00_utils/non_parametric_collocation.py:95: UserWarning: Data transposed to match expected dimensions.
#   warnings.warn("Data transposed to match expected dimensions.")

# %%
layer_widths = [2, 20, 2]

tol = 1e-2
params = {"tol":1e-2, 
          "dual_inf_tol": tol, 
          "compl_inf_tol": tol,
          "constr_viol_tol": tol, 
          
          # repeat the same for the acceptable tolerances
          "acceptable_tol": 1e-15,
          "acceptable_constr_viol_tol": 1e-15,
          "acceptable_dual_inf_tol": 1e-15,
          "acceptable_compl_inf_tol": 1e-15,
          "acceptable_iter": 0, 
          
          "halt_on_ampl_error" : 'yes',
          "print_level": 5, 
          #"hessian_approximation": 'limited-memory', 
          #"mu_strategy": 'adaptive', 
          #"check_derivatives_for_naninf": 'yes',
          "max_iter": 1000}

start_timer_build = time.time()
ode_model = NeuralODEPyomo_cont(np.array(y_noisy_vdp), # y
                        np.array(t_vdp), # t
                        np.array(D_vdp),
                        
                        layer_widths, act_func = "tanh", 
                        y_init = np.array(estimated_solution_vdp), 
                        penalty_lambda_reg = 0.1, 
                        time_invariant = True,
                        # extra_input 
                        w_init_method = 'xavier', 
                        params = params,
                        deriv_method = "collocation",
                        is_continuous = True
                        )

ode_model.build_model()
end_timer_build = time.time()
result = ode_model.solve_model()
u_model = ode_model.extract_solution()
# Out:
# Ipopt 3.14.16: tol=0.01
# dual_inf_tol=0.01
# compl_inf_tol=0.01
# constr_viol_tol=0.01
# acceptable_tol=1e-15
# acceptable_constr_viol_tol=1e-15
# acceptable_dual_inf_tol=1e-15
# acceptable_compl_inf_tol=1e-15
# acceptable_iter=0
# halt_on_ampl_error=yes
# print_level=5
# max_iter=1000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.16, running with linear solver MUMPS 5.7.1.
#
# Number of nonzeros in equality constraint Jacobian...:   112236
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:    40681
#
# Total number of variables............................:      502
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      502
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      398
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.2132583e+01 5.26e+00 7.72e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  3.6948768e+01 2.19e+00 3.36e+02  -1.0 1.41e+00   2.0 8.12e-01 1.00e+00h  1
#    2  4.9269120e+01 9.83e-01 7.08e+03  -1.0 5.01e-01   3.3 9.87e-01 1.00e+00h  1
#    3  6.4235176e+01 6.90e-01 1.57e+05  -1.0 5.97e-01   4.7 1.00e+00 1.00e+00H  1
#    4  6.8811038e+01 2.44e-01 1.08e+06  -1.0 2.28e-01   6.0 1.00e+00 1.00e+00h  1
#    5  7.0114259e+01 8.44e-02 3.94e+05  -1.0 2.06e-01   6.4 1.00e+00 1.00e+00h  1
#    6  6.9915070e+01 9.05e-03 3.43e+05  -1.0 5.29e-02   5.9 1.00e+00 1.00e+00h  1
#    7  6.9858522e+01 5.97e-05 6.69e+03  -1.0 3.08e-03   6.4 1.00e+00 1.00e+00h  1
#    8  6.9857610e+01 3.52e-09 2.57e+01  -1.0 3.04e-05   5.9 1.00e+00 1.00e+00h  1
#    9  6.9857127e+01 2.65e-10 1.75e+00  -1.0 6.84e-06   5.4 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  6.9855677e+01 2.39e-09 1.75e+00  -1.0 2.05e-05   4.9 1.00e+00 1.00e+00f  1
#   11  6.9851327e+01 2.15e-08 1.75e+00  -1.0 6.16e-05   4.5 1.00e+00 1.00e+00f  1
#   12  6.9838283e+01 1.93e-07 1.75e+00  -1.0 1.85e-04   4.0 1.00e+00 1.00e+00f  1
#   13  6.9799181e+01 1.74e-06 1.75e+00  -1.0 5.54e-04   3.5 1.00e+00 1.00e+00f  1
#   14  6.9682174e+01 1.56e-05 1.75e+00  -1.0 1.66e-03   3.0 1.00e+00 1.00e+00f  1
#   15  6.9333796e+01 1.40e-04 1.74e+00  -1.0 4.96e-03   2.5 1.00e+00 1.00e+00f  1
#   16  6.8311971e+01 1.23e-03 1.72e+00  -1.0 1.47e-02   2.1 1.00e+00 1.00e+00f  1
#   17  6.5443491e+01 1.05e-02 1.65e+00  -1.0 4.25e-02   1.6 1.00e+00 1.00e+00f  1
#   18  5.8305980e+01 7.87e-02 1.48e+00  -1.0 1.15e-01   1.1 1.00e+00 1.00e+00f  1
#   19  4.4101526e+01 1.45e+00 2.92e+00  -1.0 1.33e+00   0.6 1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  3.8980019e+01 3.30e-01 4.39e+00  -1.0 3.01e-01   1.1 1.00e+00 1.00e+00h  1
#   21  3.8182230e+01 4.91e-02 4.98e+00  -1.0 1.61e-01   1.5 1.00e+00 1.00e+00h  1
#   22  3.2355268e+01 2.12e+00 6.46e+00  -1.0 6.69e-01   1.0 1.00e+00 1.00e+00f  1
#   23  3.0798003e+01 3.79e-01 1.33e+01  -1.0 2.31e-01   1.4 1.00e+00 1.00e+00h  1
#   24  3.0436715e+01 1.07e-02 4.51e+00  -1.0 4.98e-02   1.9 1.00e+00 1.00e+00h  1
#   25  2.9034627e+01 6.41e-03 1.11e+00  -1.0 3.30e-02   1.4 1.00e+00 1.00e+00f  1
#   26  2.5719616e+01 4.07e-02 7.60e-01  -1.0 9.37e-02   0.9 1.00e+00 1.00e+00f  1
#   27  2.0410323e+01 1.88e-01 5.42e-01  -1.7 2.69e-01   0.4 1.00e+00 1.00e+00f  1
#   28  1.9023840e+01 1.37e-02 4.69e-01  -1.7 6.59e-02   0.9 1.00e+00 1.00e+00h  1
#   29  1.7396457e+01 5.17e-02 3.14e-01  -1.7 1.27e-01   0.4 1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  1.6243168e+01 1.83e-01 2.47e-01  -1.7 2.70e-01  -0.1 1.00e+00 1.00e+00h  1
#   31  1.6142536e+01 1.16e+00 2.44e+00  -1.7 2.52e+00  -0.6 1.00e+00 5.00e-01h  2
#   32  1.5361972e+01 1.24e+00 1.80e+00  -1.7 6.04e-01  -0.1 1.00e+00 1.00e+00h  1
#   33  1.5492913e+01 3.34e-01 1.53e+00  -1.7 3.10e-01   0.3 1.00e+00 1.00e+00h  1
#   34  1.5599731e+01 2.22e-02 8.16e-02  -1.7 9.63e-02  -0.2 1.00e+00 1.00e+00h  1
#   35  1.5567694e+01 3.72e-02 5.95e-02  -2.5 1.89e-01  -0.7 1.00e+00 1.00e+00h  1
#   36  1.5554038e+01 7.36e-02 2.59e-01  -2.5 5.31e-01  -1.2 1.00e+00 5.00e-01h  2
#   37  1.5469008e+01 2.72e-01 7.83e-02  -2.5 5.32e-01  -1.6 1.00e+00 1.00e+00H  1
#   38  1.5537939e+01 1.34e-01 1.91e-01  -2.5 1.15e+00  -2.1 1.00e+00 5.00e-01h  2
#   39  1.5550817e+01 1.37e-01 3.11e-01  -2.5 6.12e+00  -1.7 1.00e+00 3.12e-02h  6
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  1.5498774e+01 1.65e-01 6.21e-01  -2.5 3.48e-01  -0.4 1.00e+00 5.00e-01h  2
#   41  1.5258598e+01 1.15e+00 8.46e+00  -2.5 6.79e-01   0.1 1.00e+00 1.00e+00h  1
#   42  1.3945082e+01 1.14e-01 1.08e+01  -2.5 1.41e-01   1.4 1.00e+00 1.00e+00h  1
#   43  1.3655756e+01 9.07e-03 2.35e+00  -2.5 4.27e-02   1.8 1.00e+00 1.00e+00h  1
#   44  1.3389161e+01 6.15e-03 7.92e-01  -2.5 3.89e-02   1.4 1.00e+00 1.00e+00h  1
#   45  1.2692665e+01 1.57e-02 4.95e-01  -2.5 6.64e-02   0.9 1.00e+00 1.00e+00f  1
#   46  1.1811028e+01 2.75e-02 2.78e-01  -2.5 1.12e-01   0.4 1.00e+00 1.00e+00f  1
#   47  1.1391602e+01 2.45e-02 1.54e-01  -2.5 1.19e-01  -0.1 1.00e+00 1.00e+00h  1
#   48  1.1289379e+01 3.83e-02 5.02e-02  -2.5 1.90e-01  -0.6 1.00e+00 1.00e+00h  1
#   49  1.1247441e+01 7.66e-02 1.22e-01  -2.5 2.85e-01  -1.0 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  1.1213985e+01 7.65e-02 3.30e-02  -2.5 2.82e-01  -1.5 1.00e+00 1.00e+00h  1
#   51  1.1207016e+01 1.28e-01 1.97e-02  -2.5 2.57e-01    -  1.00e+00 1.00e+00h  1
#   52  1.1197983e+01 2.73e-02 2.74e-02  -2.5 2.91e-01    -  1.00e+00 1.00e+00H  1
#   53  1.1194543e+01 7.93e-03 4.91e-03  -3.0 9.25e-02    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 53
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.1194542530759948e+01    1.1194542530759948e+01
# Dual infeasibility......:   4.9142048937107540e-03    4.9142048937107540e-03
# Constraint violation....:   7.9334274526434712e-03    7.9334274526434712e-03
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.1106288044061053e-04    9.1106288044061053e-04
# Overall NLP error.......:   7.9334274526434712e-03    7.9334274526434712e-03
#
#
# Number of objective function evaluations             = 71
# Number of objective gradient evaluations             = 54
# Number of equality constraint evaluations            = 71
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 54
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 53
# Total seconds in IPOPT                               = 4.257
#
# EXIT: Optimal Solution Found.
# {'solver_time': 4.3402628898620605, 'termination_condition': <TerminationCondition.optimal: 'optimal'>, 'message': 'Ipopt 3.14.16\\x3a Optimal Solution Found'}

# %%
y0 = np.array([0.0, 1.0])
y_pred = ode_model.neural_ode(y0, t_vdp)
y1 = y_test_vdp[-1]
y_pred_test = ode_model.neural_ode(y0, t_test_vdp)

#print(f"Mean Absolute Error - Direct: {np.mean(np.abs(y_ho_cheb - u_model))}")
#print(f"Mean Absolute Error - ODE solver: {np.mean(np.abs(y_ho_cheb - y_pred))}")

#y0_test = y_test_scaled[0]
#y_pred_test = ode_model.neural_ode(y0_test, ts_test, (Xs_test, ts_test))

plt.figure(figsize=(14, 7))

plt.plot(t_test_vdp[:N], y_test_vdp[:N,0], color = 'blue', label='True Data (Train)', alpha = 0.6)
plt.plot(t_test_vdp[:N], y_test_vdp[:N,1], color = 'blue', alpha = 0.6)
plt.scatter(t_test_vdp[:N], y_pred_test[:N,0], color = 'blue', label='Predicted Trajectory (Train)', alpha = 0.6)
plt.scatter(t_test_vdp[:N], y_pred_test[:N,1], color = 'blue', alpha = 0.6)

plt.plot(t_test_vdp[N:], y_test_vdp[N:,0], color='#FF8C10', label='True Data (Test)', alpha = 0.6)
plt.plot(t_test_vdp[N:], y_test_vdp[N:,1], color='#FF8C10', alpha = 0.6)
plt.scatter(t_test_vdp[N:], y_pred_test[N:,0], color='#FF8C00', label='Predicted Trajectory (Test)', alpha = 0.6)
plt.scatter(t_test_vdp[N:], y_pred_test[N:,1], color='#FF8C00', alpha = 0.6)

plt.title("Collocation-based neural ODE training (Train and Test Sets)")
plt.legend(loc ="lower right")
plt.grid(True)
plt.show()
